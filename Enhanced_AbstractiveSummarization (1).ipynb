# %% [markdown]
# # **Business Objective**
#
# Text summarization is an active research area within data science. While text summarization techniques have a history, recent years have seen significant progress in the fields of natural language processing and deep learning. Many technology companies are actively contributing to this research and publishing research papers. Salesforce, for example, has published significant papers demonstrating state-of-the-art abstractive summarization techniques. In May 2018, a substantial milestone was achieved with the release of a sizable summarization dataset, supported by a Google Research grant.
#
# Despite the intense research activities, there is a lack of literature discussing practical applications of AI-driven summarization. Summarization is a complex task without a universal solution. Factors such as document length and content genre (e.g., technology, sports, finance, travel) significantly influence the approach to summarization. Summarizing a news article, for instance, is quite different from summarizing a financial earnings report. Consequently, the approach to summarization must be tailored to the specific use case.
#
# ---

# %% [markdown]
# # **BART Summarization Pre-Training Data Description: CNN/DM**
#
# The CNN/DailyMail dataset, as introduced by Hermann et al. in 2015, comprises 93,000 articles from CNN and 220,000 articles from the Daily Mail newspapers. Both publications include concise bullet-point summaries alongside their articles. A non-anonymized variant of this dataset can be found in the work by See et al. in 2017.
#
# To obtain this dataset, you can download and extract the stories directories for both CNN and the Daily Mail. The files are accessible for download through the terminal using the gdown tool, which can be installed with the command "pip install gdown."
#
# ---

# %%
# python version- 3.8.10 and 3.10.12(recent colab python version)
# !pip install datasets==2.9.0
# !pip install transformers==4.26.1
# !pip install pytorch_lightning==1.9.1
# !pip install torch==1.13.1+cu116
# !pip install scikit-learn==1.0.2
# !pip install pandas==1.3.5
# Out:
# Requirement already satisfied: datasets==2.9.0 in /usr/local/lib/python3.10/dist-packages (2.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (1.26.4)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (17.0.0)
# Requirement already satisfied: dill<0.3.7 in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (1.3.5)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (0.70.14)
# Collecting fsspec>=2021.11.1 (from fsspec[http]>=2021.11.1->datasets==2.9.0)
#   Downloading fsspec-2024.10.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (3.11.9)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (24.2)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (0.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.9.0) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.9.0) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.9.0) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.9.0) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.9.0) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.9.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.9.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.9.0) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.9.0) (1.18.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.9.0) (3.16.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets==2.9.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.9.0) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.9.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.9.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.9.0) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.9.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.9.0) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==2.9.0) (1.16.0)
# Downloading fsspec-2024.10.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.6/179.6 kB 6.9 MB/s eta 0:00:00
# Installing collected packages: fsspec
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2021.6.1
#     Uninstalling fsspec-2021.6.1:
#       Successfully uninstalled fsspec-2021.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.27.0 requires pandas>=1.5.3, but you have pandas 1.3.5 which is incompatible.
# bigframes 1.27.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.3.5 which is incompatible.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.26.1 which is incompatible.
# Successfully installed fsspec-2024.10.0
# Requirement already satisfied: transformers==4.26.1 in /usr/local/lib/python3.10/dist-packages (4.26.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.26.1) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.26.1) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers==4.26.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.26.1) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.26.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.26.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.26.1) (2024.8.30)
# Requirement already satisfied: pytorch_lightning==1.9.1 in /usr/local/lib/python3.10/dist-packages (1.9.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.1) (1.26.4)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.1) (2.5.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.1) (4.66.6)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.1) (6.0.2)
# Requirement already satisfied: fsspec>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (2024.10.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.1) (1.6.0)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.1) (24.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.1) (4.12.2)
# Requirement already satisfied: lightning-utilities>=0.6.0.post0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning==1.9.1) (0.11.9)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (3.11.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.6.0.post0->pytorch_lightning==1.9.1) (75.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.1) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.1) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch_lightning==1.9.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->pytorch_lightning==1.9.1) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->pytorch_lightning==1.9.1) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning==1.9.1) (3.10)
# ERROR: Could not find a version that satisfies the requirement torch==1.13.1+cu116 (from versions: 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0, 2.1.1, 2.1.2, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.4.0, 2.4.1, 2.5.0, 2.5.1)
# ERROR: No matching distribution found for torch==1.13.1+cu116
# Requirement already satisfied: scikit-learn==1.0.2 in /usr/local/lib/python3.10/dist-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0.2) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0.2) (1.13.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0.2) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.0.2) (3.5.0)
# Requirement already satisfied: pandas==1.3.5 in /usr/local/lib/python3.10/dist-packages (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (2024.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas==1.3.5) (1.26.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.5) (1.16.0)

# %%
# !pip install datasets==1.6.2
# !pip install fsspec==2021.6.1
# Out:
# Collecting datasets==1.6.2
#   Using cached datasets-1.6.2-py3-none-any.whl.metadata (9.2 kB)
# WARNING: Ignoring version 1.6.2 of datasets since it has invalid metadata:
# Requested datasets==1.6.2 from https://files.pythonhosted.org/packages/46/1a/b9f9b3bfef624686ae81c070f0a6bb635047b17cdb3698c7ad01281e6f9a/datasets-1.6.2-py3-none-any.whl has invalid metadata: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     pyarrow (>=1.0.0<4.0.0)
#             ~~~~~~~~^
# Please use pip<24.1 if you need to use this version.
# ERROR: Could not find a version that satisfies the requirement datasets==1.6.2 (from versions: 0.0.9, 1.0.0, 1.0.1, 1.0.2, 1.1.0, 1.1.1, 1.1.2, 1.1.3, 1.2.0, 1.2.1, 1.3.0, 1.4.0, 1.4.1, 1.5.0, 1.6.0, 1.6.1, 1.6.2, 1.7.0, 1.8.0, 1.9.0, 1.10.0, 1.10.1, 1.10.2, 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 1.13.2, 1.13.3, 1.14.0, 1.15.0, 1.15.1, 1.16.0, 1.16.1, 1.17.0, 1.18.0, 1.18.1, 1.18.2, 1.18.3, 1.18.4, 2.0.0, 2.1.0, 2.2.0, 2.2.1, 2.2.2, 2.3.0, 2.3.1, 2.3.2, 2.4.0, 2.5.0, 2.5.1, 2.5.2, 2.6.0, 2.6.1, 2.6.2, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.10.0, 2.10.1, 2.11.0, 2.12.0, 2.13.0, 2.13.1, 2.13.2, 2.14.0, 2.14.1, 2.14.2, 2.14.3, 2.14.4, 2.14.5, 2.14.6, 2.14.7, 2.15.0, 2.16.0, 2.16.1, 2.17.0, 2.17.1, 2.18.0, 2.19.0, 2.19.1, 2.19.2, 2.20.0, 2.21.0, 3.0.0, 3.0.1, 3.0.2, 3.1.0)
# ERROR: No matching distribution found for datasets==1.6.2
# Collecting fsspec==2021.6.1
#   Using cached fsspec-2021.6.1-py3-none-any.whl.metadata (5.2 kB)
# Using cached fsspec-2021.6.1-py3-none-any.whl (115 kB)
# Installing collected packages: fsspec
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.27.0 requires fsspec>=2023.3.0, but you have fsspec 2021.6.1 which is incompatible.
# bigframes 1.27.0 requires pandas>=1.5.3, but you have pandas 1.3.5 which is incompatible.
# bigframes 1.27.0 requires scikit-learn>=1.2.2, but you have scikit-learn 1.0.2 which is incompatible.
# cudf-cu12 24.10.1 requires pandas<2.2.3dev0,>=2.0, but you have pandas 1.3.5 which is incompatible.
# dask 2024.10.0 requires fsspec>=2021.09.0, but you have fsspec 2021.6.1 which is incompatible.
# datasets 2.9.0 requires fsspec[http]>=2021.11.1, but you have fsspec 2021.6.1 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2021.6.1 which is incompatible.
# huggingface-hub 0.26.3 requires fsspec>=2023.5.0, but you have fsspec 2021.6.1 which is incompatible.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.26.1 which is incompatible.
# Successfully installed fsspec-2021.6.1

# %%
from datasets import load_dataset, list_datasets

datasets = list_datasets()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %% [markdown]
# Permalink: https://huggingface.co/datasets/viewer/?dataset=cnn_dailymail&config=3.0.0

# %%
from pprint import pprint

print(f"🤩 Currently {len(datasets)} datasets are available on the hub:")
pprint(datasets, compact=True)
# Out:
# Streaming output truncated to the last 5000 lines.
#  'tintnguyen/generated-viwiki-questions-negs-2', 'Dipl0/ASL_tokens',
#  'liangzid/robench-eval-Time28-s', 'HashBigBro/gms8k_gemma_qwen2.5',
#  'howl-anderson/Game-Oracle_DOTA2-Match-Prediction-Dataset',
#  'DrissDo/half_vietnamese_curated_dataset',
#  'achnew001/Consolidated-Open-Source-Dataset-for-Global-Wellbeing-and-Sustainability',
#  'Kucharek9/Airforce1_project', 'liangzid/robench-eval-Time29-s',
#  'ABrain-One/nn-dataset', 'VladislavKaryukin/AmericanEnglishTTS',
#  'aysekaya/turkishTextToSql-ds', 'neoneye/simon-arc-combine-v197',
#  'richardodliu/leetcode_test',
#  'Mateusz1017/company_reports_features_combined_full',
#  'aaditya-aub/desktop-element-detection-001',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_90a4eb58-04d7-41b3-828d-c5bd2dd28d49',
#  'liangzid/robench-eval-Time30-s',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_05840ecd-6f70-4784-ac29-38e013ea4ee7',
#  'rssaem/btsdataL_kor',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_57612550-2c18-468b-b26a-510ceb8ea742',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_8fbd838d-702e-4803-8856-f8fbed84b39c',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_1cd90e20-bbb4-416d-becd-84b7c883b7fc',
#  'albertvillanova/tmp-file-upload', 'wzhang472/HIT', 'Eloonwu/aloha_test',
#  'paolordls/crosslg-contaminated-benchmark-qa-en-og-sm-0', 'Sinario/hypersdt',
#  'mwilliams31/capa-role', 'Eloonwu/so100_test',
#  'liangzid/robench-eval-Time31-s',
#  'open-llm-leaderboard/nbeerbower__Mistral-Nemo-Prism-12B-v2-details',
#  'Razvan27/artifical_data', 'NbAiLab/nb_distil_speech_noconcat_nst',
#  'Razvan27/artificial_data', 'chendelong/goalsteps_cooking_40_fps',
#  'JeromeUwU/RecipeFineTune',
#  'open-llm-leaderboard/nbeerbower__Mistral-Nemo-Prism-12B-v7-details',
#  'ylacombe/emilia-subset', 'liangzid/robench-eval-Time0-c',
#  'Aditya2411/law_india', 'aliberts/reachy_wave',
#  'afg1/rat_transcript_classification_data', 'BazeBai/ECM_features',
#  'jinunyachhyon/Acceptabiliity_Judgement_Benchmark',
#  'open-llm-leaderboard/nbeerbower__Nemo-Loony-12B-experimental-details',
#  'lewtun/test-fast-parser-l1b-v2', 'liangzid/robench-eval-Time1-c',
#  'AIForge/evolved-hermes', 'riczhou/hermes-function-calling-v1-split',
#  'open-llm-leaderboard/nbeerbower__Mistral-Nemo-Moderne-12B-FFT-experimental-details',
#  'open-llm-leaderboard/nbeerbower__SmolNemo-12B-FFT-experimental-details',
#  'neoneye/simon-arc-combine-v198', 'yubinnii/ikea_atmosphere',
#  'liangzid/robench-eval-Time2-c', 'chendelong/goalsteps_cooking_48_fps',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_628d2c58-6ab1-44cb-92b6-18f45d24ae01',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_e96f1f8d-b420-463d-985d-15e617d8b5fb',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_d8fa9656-52c8-4edd-a477-efa116e2f8ac',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_447f1f6a-000f-48ef-9dfd-cbdf35c8eb7d',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_e299e2e9-5a17-4eed-9a1f-23e9228d54b9',
#  '16-Bytes/banana', 'jfcalvo/export-testing-261', 'tuna2134/txt2ph',
#  'neuronbit/uaspeech_train', 'kim586w/car_damage_sample',
#  'anastasiafrosted/endpoint1', 'leleleo/igao', 'neuronbit/uaspeech_test',
#  'liangzid/robench-eval-Time3-c', 'ryota39/hh-rlhf',
#  'dgambettaphd/D_gen5_run1_llama2-7b_wiki_doc1000_real32_synt96',
#  'jfcalvo/export-testing-262',
#  'paolordls/crosslg-contaminated-benchmark-qa-en-og-sm-1',
#  'jfcalvo/export-testing-263', 'LongThan/Hallucination_MLLMs',
#  'kim586w/car_damage_sample_with_images', 'Danasoumoh/phase2',
#  'liangzid/robench-eval-Time4-c', 'chendelong/goalsteps_cooking_64_fps',
#  'jfcalvo/export-testing-264', 'thytruc/text-error', 'win10/22',
#  'bpd1997/guanaco-llama2-1k',
#  'Nayana-cognitivelab/Nayana-Seed-en-100k-safedocs-layouts',
#  'muhammadravi251001/restructured_xnli',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_31a1a0f8-861c-44fb-a6c3-e89d3665bf62',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_8177bd4c-c0d3-46d8-a735-e076514d5911',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_b6f12550-f1f3-4a24-bd67-fe9ae6a827df',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_5435b4b3-8356-4f6a-a420-665063ee83ce',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2f8ec016-33c8-4a80-87cb-840712159229',
#  'mahdiR128/fiting_clothes_in_body_2', 'llm87/semcor_transformed',
#  'quanliang/Fractography_test',
#  'beomi/kowikitext-qa-ref-detail-preview-1k-oai-raft-sample',
#  'liangzid/robench-eval-Time5-c', 'mahdiR128/fiting_clothes_in_body_1',
#  'afolabibenjamenn/web3fixer', 'DavesArmoury/block_test',
#  'liangzid/robench-eval-Time6-c', 'hcaoaf/MoleculeQA',
#  'jfcalvo/export-testing-265', 'liangzid/robench-eval-Time7-c',
#  'jfcalvo/export-testing-266', 'chendelong/goalsteps_cooking_14_fps',
#  'quyanh/ms3301-refine', 'andrejaystevenson/gege', 'timothy0503/saycan-plan',
#  'lewtun/test-fast-parser-l1b-v3', 'liangzid/robench-eval-Time8-c',
#  'quyanh/loigiaihay-refine', 'tony-pitchblack/news-segmentation-NTV',
#  'cfahlgren1/gpt-4o-traces', 'bobbyDiggs/my-face-images',
#  'liangzid/robench-eval-Time9-c', 'Simonlob/Wake_word_Akylai',
#  'YuxinJiang/new_web_math_code_section_sft_100k_v6_new_2v1_llama3',
#  'artnoage/dpo3', 'chendelong/goalsteps_cooking_13_fps',
#  'andreina-covi/vqasynth_sample_spatial_new',
#  'forgetfulSong/F990_Religious_Orgs_Curated_target_v2',
#  'Nayana-cognitivelab/Nayana-Seed-en-100k-safedocs',
#  'chendelong/goalsteps_cooking_15_fps', 'liangzid/robench-eval-Time10-c',
#  'clw8998/NER-step-by-step-dataset', 'ai-ml-lab/scrapped-asu-data',
#  'simonycl/ultrafeedback_binarized_gold',
#  'simonycl/ultrafeedback_binarized_raw',
#  'violetxi/NUMINA-V2-Clean-Blocks-1800_2000-0_5',
#  'neoneye/simon-arc-combine-v199', 'liangzid/robench-eval-Time11-c',
#  'khsquarepants/cartoon-blip-captions', 'thytruc/text-error-1',
#  'dtankdempsey/epgshare01_all_sources', 'liangzid/robench-eval-Time12-c',
#  'ManoharPalanisamy/NL2SQL',
#  'simonycl/ultrafeedback_binarized_raw-annotate-judge-mtbench_cot_truth',
#  'sadik0303/people', 'PromptEval/MMLU_multi_prompt_v0',
#  'aliberts/reachy_wave_2',
#  'open-llm-leaderboard/aloobun__d-SmolLM2-360M-details',
#  'multi-domain-reasoning/gsm8k_eval', 'ruhwang2001/EV_on_Demand_USA',
#  'liangzid/robench-eval-Time13-c',
#  'dgambettaphd/D_gen6_run1_llama2-7b_wiki_doc1000_real32_synt96',
#  'thytruc/text-error-2', 'numenrider/IndianCosmeticDataset261124',
#  'liangzid/robench-eval-Time14-c', 'Svak/test', 'adjeNole/EHRSQL_DIRECT_PROMPT',
#  'liangzid/robench-eval-Time15-c', 'gigant/cnn_dailymail_oreo_1k',
#  'rzt/water_image', 'PeterJBlake/model_test_slang',
#  'multi-domain-reasoning/mmlu_eval', 'muhammadravi251001/restructured_massive',
#  'SHRemon97/VQA_Rad_Train_Test_F1', 'PeterJBlake/model_test_stopwords',
#  'liangzid/robench-eval-Time16-c', 'PeterJBlake/model_test_typos',
#  'darrylnurse/york-share-gpt',
#  'JinchuanTian/speechlm_asr_tts_lm_wavlm_uniaudio_v1', 'jimmychuu/insults',
#  'dalssy/data_del', 'liangzid/robench-eval-Time17-c',
#  'open-llm-leaderboard/FlofloB__83k_continued_pretraining_Qwen2.5-0.5B-Instruct_Unsloth_merged_16bit-details',
#  'Kaballas/latest', 'neuronbit/uaspeech_train_casted',
#  'neuronbit/uaspeech_test_casted', 'liangzid/robench-eval-Time18-c',
#  'sami-elsaeyed11/wav2vec2-arabic',
#  'theonlyamos/ghanaian_languages_to_english_translation_and_transcription_dataset',
#  'Olat2/sp500_Price_Dataset', 'LongThan/Hallucination_MLLMs_Data_preprocessing',
#  'Olat2/sp500_ESG_Dataset', 'hsp0509/hsp', 'Jtraxler/Event_Intention',
#  'liangzid/robench-eval-Time19-c', 'rehabyehia/rev3_9463_tv_news_arabic',
#  'anassaleh218/finetuning_demo', 'liangzid/robench-eval-Time20-c',
#  'Mahler60/yuuka_lore', 'yzimmermann/tokenized-4m',
#  'RylanSchaeffer/collapse_gemma-2-27b_hs2_replace_iter2_sftsd1_temp1_max_seq_len512',
#  'liangzid/robench-eval-Time21-c',
#  'RylanSchaeffer/collapse_gemma-2-27b_hs2_replace_iter2_sftsd0_temp1_max_seq_len512',
#  'josheire/british_top_media_news_2021_thru_2024',
#  'tcapelle/ToxicCommons-balanced',
#  'dgambettaphd/D_gen7_run1_llama2-7b_wiki_doc1000_real32_synt96',
#  'vsamuel/function_calling_split', 'liangzid/robench-eval-Time22-c',
#  'cucinell96/BVBRC-Eval1',
#  'sami-elsaeyed11/wav2vec2-large-xls-r-300m-arabic-colab',
#  'Noggerone/finetuning_demo', 'SeppeV/joke_gen_of_mistral_ft_double_dpo_10pc',
#  'StanfordAIMI/StructUtterances',
#  'violetxi/NUMINA-V2-Clean-Blocks-1800_2000-5_95',
#  'paolordls/crosslg-contaminated-benchmark-qa-en-og-sm-2',
#  'liangzid/robench-eval-Time23-c',
#  'violetxi/NUMINA-V2-Clean-Blocks-1400_1600-4_39',
#  'amuvarma/combined-shuffled-text-orca-ds',
#  'amuvarma/combined-shuffled-dev-text-orca-ds',
#  'RylanSchaeffer/collapse_gemma-2-27b_hs2_replace_iter2_sftsd2_temp1_max_seq_len512',
#  'neoneye/simon-arc-combine-v200',
#  'LongThan/Hallucination_MLLMs_hallucinated_ques',
#  'liangzid/robench-eval-Time24-c', 'plaguss/test_math_shepherd_prm_temp_08',
#  'HariVaradhan/Bail-legal-documents-dataset', 'beanham/spatial_join_dataset',
#  'JuliaBiwan/multi', 'liangzid/robench-eval-Time25-c', 'maxmnd/dataset3.2',
#  'plaguss/test_math_shepherd_prm_temp05', 'amuvarma/text-dev-0-processed-0',
#  'ssrisunt/chess_pieces', 'liangzid/robench-eval-Time26-c',
#  'liangzid/robench-eval-Time27-c', 'amuvarma/text-dev-0-processed-1',
#  'Bainbridge/filtered_wikipedia_gnt-v1', 'matunderstars/ufes-qa-data',
#  'TDN007/arc_challenge_de_fixed', 'liangzid/robench-eval-Time28-c',
#  'Vinisf/Vini5reup', 'Price222/TFM-Bot', 'annsofo/finchai-re-director-of',
#  'amuvarma/orcatext-dev-processed-2', 'liangzid/robench-eval-Time29-c',
#  'Gabooooong/gabongo', 'glampirelabs/autotrain-ali-images',
#  'IanAndJohn/imgs_with_metadata', 'Gaming031123/disaster_images',
#  'liangzid/robench-eval-Time30-c',
#  'dgambettaphd/D_gen8_run1_llama2-7b_wiki_doc1000_real32_synt96',
#  'amuvarma/orcatext-200k-processed-1', 'liangzid/robench-eval-Time31-c',
#  'autoprogrammer/nllb_eng_Latn_jpn_Jpan_subset_15k',
#  'neoneye/simon-arc-combine-v201', 'sartifyllc/www-jamiiforums-com',
#  'deivism/meddocan_labels21', 'HariVaradhan/bail-legal-documents-dataset-JSON',
#  'liangzid/robench-eval-Time0-p', 'Neyto/MarceloRezende',
#  'jeremierostan/Fake_WiLlama', 'liangzid/robench-eval-Time1-p',
#  'gpellejero/df_test', 'HumanLLMs/MistralPair', 'HumanLLMs/LlamaPair',
#  'HumanLLMs/QwenPair', 'AliMostafaRadwan/test_new_format',
#  'liangzid/robench-eval-Time2-p', 'dakopi/algebra__linear_1d',
#  'AliMostafaRadwan/test_new_editedQ', 'liangzid/robench-eval-Time3-p',
#  'KarthikaRajagopal/audio.webm', 'Ahmed107/eosv3', 'hzlama/MM-Fabric',
#  'liangzid/robench-eval-Time4-p', 'ma-xu/seed123', 'naresh810/Law',
#  'FastVideo/Mochi-425-Data', 'liangzid/robench-eval-Time5-p',
#  'KarthikaRajagopal/fake_news.h5', 'Rakuto/aicon-pois',
#  'yzimmermann/tokenized-ZINC-1B', 'allenhung1025/leetcode',
#  'Pap0/sora-video-dataset', 'liangzid/robench-eval-Time6-p', 'Ahmed107/eosv4',
#  'KarthikaRajagopal/Restaurant_Reviews.tsv', 'danjacobellis/chestmnist_224',
#  'earthnets/GAMUS', 'SeppeV/joke_gen_of_mistral_ft_double_dpo_10pc_jo',
#  'liangzid/robench-eval-Time7-p', 'earthnets/BigEarthNet',
#  'earthnets/BigEarthNetV2', 'earthnets/Eurosat', 'earthnets/UrbanSARFloodsV1',
#  'dgambettaphd/D_gen9_run1_llama2-7b_wiki_doc1000_real32_synt96',
#  'earthnets/AID',
#  'SeppeV/results_joke_gen_of_mistral_ft_double_dpo_10pc_jo_ens_test',
#  'Samoed/AppsRetrieval', 'skdrx/python-dpo-dataset-varname-formatted',
#  'danjacobellis/pneumoniamnist_224',
#  'SeppeV/results_joke_gen_mistral_ft_mean_score_dpo_ens_10pc_test',
#  'isaacchung/flickr30ki2t', 'liangzid/robench-eval-Time8-p',
#  'xCj123x/Tripadvisor_reviews', 'danjacobellis/dermamnist_224',
#  'llk010502/fingpt-sentiment', 'isaacchung/flickr30kt2i',
#  'harshildarji/Reber-Grammar', 'liangzid/robench-eval-Time9-p',
#  'danjacobellis/organsmnist_224', 'danjacobellis/retinamnist_224',
#  'danjacobellis/breastmnist_224', 'neoneye/simon-arc-combine-v202',
#  'liangzid/robench-eval-Time10-p', 'hijohnnylin/sae-evals',
#  'neuronpedia/sae-evals', 'Erland/f_n_d_d_c_l_f_u_s_c',
#  'liangzid/robench-eval-Time11-p', 'vouu/reddit_dataset_187',
#  'vouu/x_dataset_187', 'danjacobellis/organamnist_224',
#  'open-llm-leaderboard/recoilme__recoilme-gemma-2-9B-v0.5-details',
#  'faizulsami/images', 'liangzid/robench-eval-Time12-p',
#  'ychen/empathetic-dialogues-persona-instruct',
#  'Bainbridge/filtered_wikipedia_gnt-v2', 'naishagarwal/vaporwave-dataset',
#  'DreamIndex/ATLAS', 'kojikubota/Fractal-Consciousness-Prompt',
#  'amuvarma/contentonly-raw-dev-4k', 'amuvarma/contentonly-raw-train-1m',
#  'liangzid/robench-eval-Time13-p', 'amuvarma/contentonly-raw-dev-4k-1dups',
#  'amuvarma/contentonly-proc-dev-4k-1dups', 'multitensor/qvhilights',
#  'liangzid/robench-eval-Time14-p',
#  'amuvarma/contentonly-proc-dev-800-1dups-concat',
#  'jjz5463/DoorDash_synthetic_sitemap', 'liangzid/robench-eval-Time15-p',
#  'ricebucket/ratemyprofessor_comments_stars_difficulties_tags',
#  'akrishnan/counterfactuals', 'amuvarma/contentonly-train-1m-1dups',
#  'Lavador/Vocal_Mano', 'liangzid/robench-eval-Time16-p',
#  'dgambettaphd/D_gen10_run1_llama2-7b_wiki_doc1000_real32_synt96',
#  'Lavador/Mano_Vocal', 'danjacobellis/tissuemnist_224',
#  'jlau0228/flowermeanings', 'liangzid/robench-eval-Time17-p',
#  'cnmoro/smoltalk-555k-ptbr', 'nivaangupta/unicc-text-binary',
#  'steven2521/mst_cot', 'liangzid/robench-eval-Time18-p',
#  'amuvarma/contentonly-proc-train-1m-1dups', 'neody/smoltalk_bit_filtered',
#  'BEE-spoke-data/fingpt-all', 'MinaMila/CFA_adult_train_ImpFeat',
#  'anakib1/mango-ria', 'liangzid/robench-eval-Time19-p',
#  'sartifyllc/swahili_DPO_uncleaned',
#  'mlfoundations-dev/camel_chemistry_gpt-4o-mini_1x',
#  'rehabyehia/filtered_wav_dataset', 'liangzid/robench-eval-Time20-p',
#  'amuvarma/contentonly-proc-train-200k-1dups-concat',
#  'open-llm-leaderboard/cpayne1303__cp2024-details',
#  'mlfoundations-dev/camel_biology_gpt-4o-mini_1x',
#  'liangzid/robench-eval-Time21-p', 'neoneye/simon-arc-combine-v203',
#  'mlfoundations-dev/webinstruct_stage_1_2', 'parth51/dealignment-dataset',
#  'liangzid/robench-eval-Time22-p',
#  'amuvarma/contentonly-proc-train-125k-1dups-concat-pad',
#  'mlfoundations-dev/camel_math_gpt-4o-mini_1x',
#  'liangzid/robench-eval-Time23-p', 'mint-multix/eval_results', 'deadman80/Aiii',
#  'Marcusxx/CngFSt10_5_sec', 'qfq/quant', 'liangzid/robench-eval-Time24-p',
#  'qfq/cot-portfolio', 'swap-uniba/il_calderone',
#  'liangzid/robench-eval-Time25-p', 'dogtooth/tulu_8b_generated_uf',
#  'timaeus/max_delta_ablation_l0h1', 'thytruc/text-error-3',
#  'opentunes-ai/melodymaster-v1', 'Kiliemah/llmtwin', 'kickbuttascii/GS',
#  'saghdgsa/DASDASD', 'liangzid/robench-eval-Time26-p',
#  'aditya9056/finetuning_demo', 'apol/my-distiset-64eab852', 'deskpai-com/data',
#  'liangzid/robench-eval-Time27-p', 'violetxi/NuminaMath-TIR-Filtered',
#  'reinashi/best_movie_adaptations', 'liangzid/robench-eval-Time28-p',
#  'violetxi/NUMINA-V2-Clean-Blocks-1400_1600-39_45', 'allenai/clocks',
#  'violetxi/NUMINA-V2-Clean-Blocks-10000_10500-90_100',
#  'liangzid/robench-eval-Time29-p', 'danjacobellis/pathmnist_224',
#  'neoneye/simon-arc-combine-v204',
#  'rr4433/Powershell_Malware_Detection_Dataset',
#  'ielabgroup/stella_trec24_biogen_embedding', 'liangzid/robench-eval-Time30-p',
#  'gokulsrinivasagan/processed_book_corpus', 'checkzz/fangdichan',
#  'liangzid/robench-eval-Time31-p', 'apoorvkh/whoswaldo',
#  'danjacobellis/organcmnist_224', 'njPakr/medical_chatbot_dataset',
#  'CR34T10N-ST4T10N/st34mb04t-Mixed', 'danjacobellis/bloodmnist_224',
#  'riczhou/hermes-function-calling-v1-glaive-split', 'CHINUCO/frutasclf',
#  'stair-lab/reeval-Mistral-7B-Instruct-v0.3-sft', 'checkzz/train1',
#  'Moonglow7/123', 'eyl45/demo',
#  'DeL-TaiseiOzaki/Tengentoppa-sft-elyza-news-specialized',
#  'cc-clean/CC-MAIN-2023-23', 'thanh1231/testv2',
#  'boramaey/dss_qa_pair_from_gpt4o', 'checkzz/train',
#  'hs97013836/hgc_voice_1127', 'NESPED-GEN/spider_selector_schemaReduzido_2',
#  'Marcusxx/CngFSt10_5_sec_T_transcribe', 'win10/audio_files', 'checkzz/train2',
#  'III111II1I1/wargame-reddragon-unit-audio',
#  'DeL-TaiseiOzaki/Tengentoppa-sft-base-v1.0',
#  'violetxi/NUMINA-V2-Clean-Blocks-1800_2000-95_105',
#  'CaoLulu7829461232512/Traffic', 'gdurkin/fused_1500',
#  'Apricity0201/BrightnessAdjust', 'datnt114/test-upscale',
#  'jiachenlei/imagenet', 'sordonia/quality_sanitized', 'Shriiii/nepalitoenglish',
#  'gabrielnogueiralt/erc-specifications', 'Shriiii/englishtonepali',
#  'wangxingjun778/test_preview',
#  'violetxi/NUMINA-V2-Clean-Blocks-1400_1600-45_200',
#  'danjacobellis/octmnist_224', 'Tippawan/proof-reading-SeaLLM3-7B-Chat-3090-v1',
#  'Aligadai/danbooru-10w-zh_cn', 'leafspace/rubao_point_normal',
#  'oddadmix/flores-plus-eval', 'doanhm/faceswapimg_data', 'Lavador/Vocales_cmr',
#  'bpatel80/securesvg', 'jacklishufan/mmdit_processed_1', 'win10/4',
#  'violetxi/NUMINA-V2-Clean-Blocks-10000_10500-100_155',
#  'kevin510/act-grasp-stack-transfer', 'luca0621/multi-RLHF_turn_0_ckp',
#  'Vacuame/so100_test', 'chao1224/NeuralMD', 'win10/7',
#  'cavendishlabs/trl-mlt-1', 'cavendishlabs/trl-mlt-2', 'dnth/mini-imagenet',
#  'Tippawan/proof-reading-SeaLLM3-7B-Chat-3090-v1-shuffle', 'gptvj/vjdatabase',
#  'underctrl/single-stacked-block_mutli-color_pick-up_80', 'quangnm/CRE',
#  'gswamy/pythia-1.4B-tldr-vllm-iter-1', 'belyakoff/xlam-ru-tool-calling',
#  'SHASWATSINGH3101/Bail_pre_training', 'presencesw/open-images',
#  'stair-lab/reeval-Mistral-7B-Instruct-v0.3-ppo', 'gaomingqi/YoURVOS',
#  'Vacuame/so100', 'TNAP/testcsv', 'TNAP/testdata2',
#  'theailearner/teachingresourcesLLM', 'Wuyuhang11/doupo-dataset',
#  'Kukedlc/Spanish-Tulu-3-Selection', 'cdactvm/save_audio_tamil_numbers',
#  'sxfrul/thisisatest', 'techkiksar/india-accent-speech-data',
#  'CastGryff/multilingual_contexts', 'HashBigBro/math_qwen_gemma_qwen_rstar',
#  'Ibbi02/genai-project-dataset-without-trigger',
#  'HashBigBro/STG_llama_qwen_rstar', 'mandanya/logseq-query-clojure',
#  'Ibbi02/genai-project-dataset-with-trigger',
#  'bayrameker/defense_industry_expanded_dataset_with_damage',
#  'bayrameker/defense_industry_detailed_dataset', 'appliedml2024/text_embedding',
#  'hr99/Arabic-CivitAi-Images_split_1', 'hr99/Arabic-CivitAi-Images_split_2',
#  'AiyaFala/tokenizer_visualization', 'Klordoo/krymfol',
#  'hjoon721/AGRI_instruct_dataset', 'yenrong/classification_dataset',
#  'minjieun/qwen2.5commands', 'hyk000/gdialect', 'doanhm/faceswapvideo_data',
#  'HashBigBro/MATH_llama_qwen_rstar', 'mm-vl/Corvid-dataset',
#  'hr99/simpsons-blip-captions_split_1', 'gowtham28/processed-dataset',
#  'SMUQamar/Kashmiri-English-Dataset-270K', 'teowu/TOMATO_benchmark_videos',
#  'CR34T10N-ST4T10N/3xp3r1m3nt-001', 'llamafactory/OpenO1-SFT',
#  'Uracle-AI/intent-classification-en-5c',
#  'Uracle-AI/intent-classification-ko-5c', 'Ck242525/Ck',
#  'akhooli/ar_mmarco_dfs01', 'hyen99-03/v3_ko_Q-A_data', 'sxfrul/quizzability',
#  'tarasfrompir/latvian_sintezed', 'angelahzyuan/data-mistral-7b-instruct-iter1',
#  'angelahzyuan/data-mistral-7b-instruct-iter2',
#  'angelahzyuan/data-mistral-7b-instruct-iter3',
#  'angelahzyuan/data-mistral-7b-instruct-iter4',
#  'angelahzyuan/data-mistral-7b-instruct-iter5',
#  'angelahzyuan/data-mistral-7b-instruct-iter6', 'akhooli/ar_mmarco_dfs02',
#  'akhooli/ar_mmarco_dfs03', 'sine/FusedPALMath', 'akhooli/ar_mmarco_dfs04',
#  'jxie/language_table', 'TravelAgentProject/var-extraction',
#  'NimurAI/scrapped_organized_bg_removed_images',
#  'huyhoangt2201/fixed_error_from_contextAwareJidouka',
#  'jafarisbarov/CrimeanTatarMMLU', 'Skyler215/VILC', 'alabulei/cri-o',
#  'Exqrch/TESTPLAY', 'e34r55/image_only_train-dataset', 'erew123/rvc_pretrained',
#  'open-llm-leaderboard/Dans-DiscountModels__mistral-7b-test-merged-details',
#  'e34r55/image_only_test-dataset', 'Nishadhka/gfs_s3_gik_refs',
#  'liufanfanlff/RoboData', 'elyicipd/test', 'sine/FusedVerilogEval',
#  'mlfoundations-dev/camel_gpt-4o-mini_2x',
#  'open-llm-leaderboard/LeroyDyer__SpydazWeb_AI_HumanAI_011_INSTRUCT_ML-details',
#  'aaqil0154/epilepsy', 'DuyPham/vams_2711', 'gowtham28/math_8_to_10',
#  'open-llm-leaderboard/LeroyDyer__SpydazWeb_AI_HumanAI_011_INSTRUCT_ML_r1-details',
#  'Eka-Korn/power_line_lidar_data_test', 'tesfUTAFSA/LL',
#  'mlfoundations-dev/oh_v1.2_sin_evol_instruct_diversity',
#  'faridlazuarda/Aksara', 'siqi00/llama3_gsm8k_0.6_0.9_256_vllm', 'di2k/SAPA',
#  'mlfoundations-dev/oh_v1.2_sin_camel_math_diversity',
#  'YuxinJiang/2web_1math_1code_sft_100k_2v1_4o_mini',
#  'jinunyachhyon/Co-reference_Benchmark', 'shiqi379/new_train',
#  'mlfoundations-dev/oh_v1.2_sin_camel_biology_diversity', 'DuyPham/vamsTest',
#  'mlfoundations-dev/oh_v1.2_sin_opengpt_diversity', 'rohithbandi1/AIQUIZ',
#  'Orbina-development/tgrt-podcast-tr',
#  'open-llm-leaderboard/cpayne1303__smallcp2024-details',
#  'testmkm/masesetrt75-reduced-andten', 'testmkm/masesetrt75-reduced-andfive',
#  'mlfoundations-dev/camel_gpt-4o-mini_4x', 'tungitachi/vn-alpaca-qa',
#  'Hangyeol/train_fn_prompt', 'YuxinJiang/3web_1math_1code_sft_100k_2v1_4o_mini',
#  'AZ590357/CHINESE-NOVEL-DATASET', 'neuronbit/imperative_torgo_utterances',
#  'neuronbit/imperative_cloned_utterances', 'Erland/NLP701_Assignment2_Subtask1',
#  'neuronbit/imperative_test_utterances',
#  'mlfoundations-dev/camel_gpt-4o-mini_8x', 'yukoli/stocks-ins',
#  'yukoli/stocks-ins-train', 'yukoli/stocks-ins-valid', 'think101/data',
#  'Orbina-development/tgrt-podcast-tr-splitted',
#  'YuxinJiang/new_web_math_code_section_sft_100k_v6_new_3v1_4o_mini',
#  'Tushar018/procedure_dataset', 'swap-uniba/llava_instruct_conv_58k_ita',
#  'VenkateshBandi/FineTuneOCRdataset', 'Erland/NLP701_Assignment2_Subtask2',
#  'spralannny/anfang', 'lamblamb/pile_of_law_subset', 'hjoon721/final_output2',
#  'nappa0326/glaive-function-calling-v2-sharegpt-japanese',
#  'r1v3r/data_classification', 'timmylee0624/finetuning_demo', 'nlile/24-game',
#  'xuefen/VulResource',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_14974d9f-8178-4e2d-8ecd-f491a8661f57',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_37b2bb3e-2693-475d-bc17-cc7b0f2d176d',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_388b5b79-7503-4062-8402-aac6ca041a72',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_5caa0024-7809-4cfd-be3e-c15b83b8ce27',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_e99f1a82-0479-4b59-8cfa-734e91acede4',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_f49a4031-c04e-4844-bb10-7a9dc60b3eaf',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_bef12560-5ee0-4159-8319-75522f69dfa0',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_861c4a25-00b9-4fb9-81fa-4682c589b14d',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2da8718e-acd5-4ac8-9fa9-f9e739e2f6a8',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_332768f6-c0d9-4974-bfca-8d1c19e138bb',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_e2017074-cd6c-4217-98a3-3d10eb5eb766',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_bccd42ac-747c-420e-9dc5-985e2caa2971',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_8ed7142b-724d-43b9-91ca-b524bc557eb6',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_86c28669-a98c-4bbc-b9c8-f97ae857d1d2',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_0fc9451d-f71a-464d-9887-8b1324a76819',
#  'jiyatai/visual_instruction_tuning_ID_reference',
#  'luca0621/multi-RLHF_turn_1_ckp', 'plaguss/test_math_shepherd_only_solutions',
#  'luca0621/multi-RLHF_turn_2_ckp', 'luca0621/multi-RLHF_turn_3_ckp',
#  'luca0621/multi-RLHF_turn_4_ckp',
#  'homebrewltd/instruction-speech-whispervq-v2-prompt-transcribe',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2405710e-cf46-44ad-ad2f-d4b14207108b',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_382fa3b3-7f02-4f59-b93c-fcb765b6df8d',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_c35a997d-bc5a-44b6-873a-c1df2281bdb6',
#  'recorderlegend1/wikitext103',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_ea450e39-0e57-45ce-8f08-1ee8e0bd8b55',
#  'rinabuoy/khmer-licence-plate', 'hmdliu/ACAC-4K',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_0aab5758-96b6-4e2a-a1d3-d86114ed199c',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_4363c339-d839-47bd-a2a3-df1fe07eaa00',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_fedc4d0a-6a1d-4850-bb01-deca9a56e9fe',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2270624a-89d0-4d88-86b4-52e5ec94245e',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_df0a0aef-f853-4b77-9ed4-9b166d2940d1',
#  'MarcosFP812/ManySstubs-Synth', 'jaff521/wends-lama3-tt',
#  'rohitschauhanitbhu/jenny-tts-tags-6h-v1',
#  'RyanYr/self-reflect_mini8Bit-t0_mistlarge-t12_om2-3', 'dongshuaijun/tike',
#  'GilbertKrantz/scientific_papers-cleaned', 'nlp-team-issai/RAG-jina',
#  'lee900624/loganomaly', 'r1v3r/asterinas_validated',
#  'luca0621/multi_RLHF_10000', '3David14/GS3LAM-Replica', 'shenmaa/PaCRISPR',
#  'shenmaa/Protein_Folding_Stability_Pred', 'woctordho/img-256-sugina',
#  'luca0621/multi_RLHF_10000_turn_0_ckp', 'namejun12000/PALR_finetuning20',
#  'namejun12000/PALR_inference1', 'namejun12000/PALR_inference2',
#  'luca0621/multi_RLHF_10000_turn_1_ckp', 'Zappu/Naver-legal-vn',
#  'Zappu/legal-docs-vn', 'r1v3r/SWE-bench_asterinas_style-3__fs-oracle',
#  'stiassny/cyberm8', 'QTeam/HT_Dictionary_filtered_top200', 'Vishal24/domain',
#  'heiung2001/codev', 'iQuxLE/example', 'neoneye/simon-arc-combine-v205',
#  'Nakulbh/turo_ai_house_prize_dataset', 'luca0621/multi_RLHF_10000_turn_2_ckp',
#  'junnystateofmind/multi-RLHF_turn_0_ckp', '3David14/TUM-DEVA',
#  'NeverWantedJr/RandomSharing',
#  'mlfoundations-dev/oh_v1.2_sin_unnatural_instructions_diversity',
#  'gaus13/turbo-ai-internal-dataset', 'junnystateofmind/multi-RLHF_turn_1_ckp',
#  'mlfoundations-dev/oh_v1.2_sin_alpaca_diversity',
#  'rohitschauhanitbhu/jenny-tts-text-tags-6h-v1', 'iQuxLE/example1',
#  'mlfoundations-dev/oh_v1.2_sin_metamath_diversity', 'clawdelu/deea-v2',
#  'iQuxLE/example2', 'miriamsventova/actors',
#  'luca0621/multi_RLHF_10000_turn_3_ckp',
#  'junnystateofmind/multi-RLHF_turn_2_ckp', 'VenkateshBandi/FineTuneOCRdataset2',
#  'Sanjid29/MINT', 'plaguss/test_math_shepherd_solutions_completions',
#  'koch3092/test-dataset', 'junnystateofmind/multi-RLHF_turn_3_ckp',
#  'MSRL-paper/MSRL-dataset', 'ybracke/dta-reviEvalCorpus-v1',
#  'luca0621/multi_RLHF_10000_turn_4_ckp', 'kuminson/test',
#  '316usman/med-qa-option-format', 'junnystateofmind/multi-RLHF_turn_4_ckp',
#  'junnystateofmind/multi-RLHF', 'youseon/Llama3_Finetuning_Train_All_Tasks',
#  'onelock/Annotation_of_Entries_from_the_Nordisk_Familjebok_Encyclopedia',
#  'myselfAdul/faqTest2', 'iQuxLE/example3',
#  '316usman/med-qa-option-with-answer-format', 'JuliaBiwan/my-new-dataset',
#  'thusken/bt-user-needs-2024', 'woctordho/img-256-swav', 'pult77/gghfgh',
#  'danier97/depthcues', 'plaguss/math-shepherd-expand-format',
#  'frozendonuts/tag-mapping', 'Neuronovo/rlhf_synthetic_generalized',
#  'mpanda27/common_voice_16_0_nl_pseudo_labelled', 'GamjaPower/sample',
#  'rohitschauhanitbhu/jenny-tts-6h-descriptions-v1',
#  'GamjaPower/baseline-prepare-dataset-500', 'fengxuanbin/ufc', 'mjcarag/MetaDS',
#  'GamjaPower/baseline-prepare-dataset',
#  'mahdiR128/fiting_clothes_in_body_mahdi', 'nazih98/carFrames',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_b0baa77d-e467-4690-baa2-32d4e2b68086',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_bd94c50d-9b49-49aa-a36a-7fa6a57a0e08',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_75946a52-b29f-48db-bfb2-ce671ab54ce3',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_fc3620f0-917d-4a07-baf1-b42561027fb1',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_115f8c4a-bc70-4c83-8109-1534134adf86',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_c6ef16da-767c-4e90-afb7-a28f3d43d4bc',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_a6e4b5d7-5bab-4879-8cc5-2a5d3c874c2a',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_0e20eea7-7f15-4256-9011-ba44890c63b9',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_54b784fb-add8-4a68-8d4b-7c6c976850f0',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_3e40b384-2b5b-4bcd-a134-43798b753bd0',
#  'thanhnghiacntt/data-vi', 'Anasrafiq/llama3.2-dataset',
#  'open-llm-leaderboard/CultriX__SeQwence-14Bv1-details', 'myselfAdul/faqTest3',
#  'ccw7463/powerplant_glossary_dataset_ver0.1', 'myselfAdul/faqTest4',
#  'open-llm-leaderboard/CultriX__SeQwence-14B-EvolMerge-details',
#  'Mekasiu1018/3', 'lanyuer/mp3s', 'dhamayanthi/crypto_QA_test',
#  'nlp-team-issai/CORE_RAG_updated', 'wangchao-raphael-2024/test_pdf',
#  'Perrykoon/UnrealChang_go', 'enikeev/tns_augmentoolkit', 'P00j4n/phil2_iio',
#  'leinad-deinor/redeIT-json-shareGPT', 'keikhosrotav/dataset-9',
#  'andersonlib/min_text_refactor', 'AnthonyKaiWu/baseline',
#  'jfcalvo/export-testing-267', 'suhwan3/eeeeeeeeee',
#  'param-bharat/completion-relevance', 'gxunda/t-mac-source',
#  'ConorHughesUK/poaching-and-phishing-data', 'keikhosrotav/dataset-10',
#  'rahul77/LaTeX55', 'RiverDong/helpsteer2-p', 'zameji/medmentions-st21pv',
#  'suhwan3/aaaaaaaaaaaaaa', 'wanderer/openai_records', 'abnerh/TORGO-database',
#  'rifoag/NLP701_Assignment2_Subtask3',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2adb7aa6-ba9a-41f6-9904-01a7cc3ea99d',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_9e90a5cb-9b3d-4b44-a77a-64d4443ea1b3',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_845b9132-df6b-49d8-9edb-a887ce834c39',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_498b75cb-6b1b-415f-a47a-697f8d448eed',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_e95de572-48bf-495e-bfc7-c51c07a2e173',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_d5c90e4d-f1db-4548-8f66-6e46225ca611',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_180d6bde-ff99-4d63-9fd4-4cb9337fa066',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2c109b0d-6f59-426b-811d-33fafa537a84',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_f9350528-bffb-46cc-abe9-ace7bbc8ccbe',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_048e4946-d167-4bc8-9af4-256392974405',
#  'jaymie23/av', 'Irshad6523/openai_records', 'lorixmassello/akka_dsl',
#  'open-llm-leaderboard/meditsolutions__Llama-3.2-SUN-1B-Instruct-details',
#  'techkiksar/indian_femail_voice_data', 'Sierkinhane/Storyboard20K',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_280066dc-b9fc-495f-93fc-6cb63948b9f2',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_80c9624c-d734-43db-995e-09db2751e89f',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_61794bcd-227b-40a5-98bd-bbdcf7b66902',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_8eb869ce-9d32-48bc-8686-7f22c6d5eb43',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_3eac3471-ef57-478b-a85f-2782be27c27b',
#  'suhwan3/1111111111', 'arnosimons/astro-hep-planck-corpus',
#  'jfcalvo/export-testing-268', 'hr99/simpsons-blip-captions_part_1',
#  'hr99/simpsons-blip-captions_part_2', 'jfcalvo/export-testing-269',
#  'tintnguyen/ir-eval', 'jfcalvo/export-testing-270',
#  'jfcalvo/export-testing-271',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_ac6f95d4-ff30-4a5e-97ab-725a4046583f',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_26fa8acc-34b1-4aa7-b0c3-b8863341252b',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2ca7dbc8-4ca0-4c2d-9883-634fc97b832c',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_a0d26b84-9806-480f-95de-97a3f3f4b0f0',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_50233528-f89b-4662-bd4d-0b47a062480d',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_1ffc0464-5c05-423d-8b64-d100ab8c4ced',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_36f401a9-5c14-4151-9547-f72203bb1795',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_5aed6061-42c2-4084-ba30-2d024ae2c690',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_e620f6c2-42d8-476e-af72-e2b63b9c8fbd',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_dde4f33f-5d59-406e-9051-a76587b4cc4e',
#  'procit007/facebookFemaleData_v1',
#  'Ibbi02/genai-project-dataset-without-trigger-100', 'heispv/protein_data_test',
#  'timaeus/max_delta_ablation_l0h2', 'ZHUI/alpaca_demo',
#  'profdiovanimerlo/cnae_2024', 'DS4H-ICTU/yat-en-translation2-new',
#  'maxglo/corel1k', 'maarijmaarijroudani/sample1',
#  'neoneye/simon-arc-combine-v206', 'Sarawut271508/kkj', 'nalisten1/Nztykle',
#  'JMSKHUG/ragas-test-dataset', 'Skyler215/KTVIC',
#  'r1v3r/SWE-bench_asterinas_bug_report__fs-oracle',
#  'open-llm-leaderboard/CultriX__SeQwence-14B-EvolMergev1-details',
#  'miladmim/slim-orca-dedup-chat-50k-persian', 'HavryliukA/token_class_2711',
#  'gedamshrutika/EN-MR', 'EduardoLawson1/MaCVi-Espelhado',
#  'jfcalvo/export-testing-272', 'procit007/STT_2.0.1_female',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_4572f2f1-57ed-46f2-96f1-f2d09e00165e',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_76336155-db80-462f-a9d9-17fec311b25a',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_87c5b61c-61cb-40ff-92fb-2992fa9bf7c8',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_91025cea-103f-4af1-8ea3-f72446c0eef8',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_4b0f7fe6-4a58-461f-a21d-ead6e5d2734b',
#  'Ulyces/met-photos', 'dankajakubkova/actors', 'JohnathonZZ/test',
#  'derek-thomas/labeled-multiple-choice-explained-mistral-reasoning',
#  'omnineura/Omni_Prepare1', 'zelk12/text_in_number_smoltalk', 'PMRCC/RCC',
#  'llm-uncertainty-head/train_akimbio_Llama-3.1-8B-Instruct',
#  'geekyrakshit/prompt-injection-dataset', 'NLPGenius/PlantDisease',
#  'llm-uncertainty-head/train_multidomain_Llama-3.1-8B-Instruct',
#  'llm-uncertainty-head/train_akimbio_Llama-2-7b-chat-hf',
#  'llm-uncertainty-head/train_multidomain_Llama-2-7b-chat-hf',
#  'Cygnuss/msc_conv', 'k4d3/furry_convention', 'Wally237/DataTest',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_77aed0d7-44a6-45db-a044-b44875e8fa84',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_5db40341-c130-4133-b96a-e8cafd9f81bb',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_b90a4d71-8c1d-44a0-8583-c723baf53585',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_27c6ef92-2dab-4973-99aa-235c93d5d9ac',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_41242f02-98a5-4e41-8994-835480a655cf',
#  'Yahya-Mohamed/arabic_audio_dataset', 'Kiliemah/llmtwin-dpo',
#  'tuan124816/cs2_data_hdf5_expert_final', 'tuan124816/cs2_data_hf_expert_final',
#  'plaguss/test_math_shepherd_01', 'adamstra/asr-wolof-dataset-processed-adams',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_a124330f-ef4a-4b50-936d-af3c41abb614',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2fb4517d-cda0-4dd5-8bf4-edbee3e9c729',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_34b1d4f0-3128-40d4-8a2a-cb7711c4ee09',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_6f5e0efb-94fc-4a1e-9095-247c4fe8a5a6',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_ab2a9d69-69ce-4fdf-aea3-0aa0844757b5',
#  'Seeker38/music_abc_notation_preprocessed',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_479d886c-4c76-4afc-bbd1-02100323ddb3',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_9630932c-81c3-479f-8370-15f9bce78d97',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_ceeaf537-a48b-4c2a-8fe5-53ea645411e2',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_2c51dc31-5b96-4fe4-8578-4feb82503eda',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_0c7f374f-50a5-404d-bb1b-4220260dd398',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_0a9ae00f-41ca-4737-8ccd-827ca4d4934a',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_3607c4f5-fa14-4af8-be78-0dbeaea6846b',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_9433e012-2e24-44d9-a2b1-52bd02d584c0',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_f55caf5c-1907-4662-b831-2eeac9275db6',
#  'argilla-internal-testing/test_import_dataset_from_hub_with_classlabel_8190cf5b-cc83-41be-9b66-1d05b7d32ad1',
#  'yjj0528/ice2', 'Punchwe/tatoeba-challenge', 'kavanamk/LOL',
#  'Ro551/corruptedText_GEC_spanish_med', 'KhoaUIT/Vietnamese-summary-dataset',
#  'Skyler215/KTVIC_VILC', 'kkkkkb/consist_four_images',
#  'GyuHyeonWkdWkdMan/lawdata', 'aliberts/eval_reachy_test',
#  'lee900624/loganomaly2', 'infinite-dataset-hub/BreastDiagnosisProgression',
#  'bikingSolo/CoolDatasetForLLM_PracLLM', 'chiki29/Aptitudedataset',
#  'Vuhu/vietname_construction', 'olgagasowska/27_11_working_code_dataset',
#  'altaidevorg/women-health-mini', 'lomit/investment_manager_mcqa',
#  'canrager/temp', 'michiel/CLEF_CT23_1A_checkworthy_multimodal_english_v2',
#  'gigant/cnn_dailymail_oreo_jinacolbertv2_0.2k', 'Dipl0/how2signclips',
#  'jfcalvo/export-testing-273', 'gigant/cnn_dailymail_oreo_jinacolbertv2_0.5k',
#  'jfcalvo/export-testing-274',
#  'open-llm-leaderboard/DreadPoor__Condensed_Milk-8B-Model_Stock-details',
#  'jfcalvo/export-testing-275', 'openpecha/OCR-Lhasakanjur',
#  'hexuan21/math-sft-mix-full-w2-sub-1', 'dogtooth/tulu_8b_generated_hs',
#  'open-llm-leaderboard/BlackBeenie__Neos-Phi-3-14B-v0.1-details',
#  'lorixmassello/Akka_Finetuning_Llama3.2', 'neoneye/simon-arc-combine-v207',
#  'mobilealohafalkenberg/toast-dataset', 'JesterLabs/UFC_FIGHT_DATA',
#  'Suman2004/MTL-Llama3-8b-Instruct', 'asoria/test_repo',
#  'ziyu3141/rich_feedbac3', 'akhooli/ar_mmarco_dfs200k_q',
#  'Moatasem444/arabic-simpsons-blip-captions', 'akhooli/ar_mmarco_dfs200k_s',
#  'ineog/autos_y_buses_ccp', 'Dipl0/test_videos', 'jfcalvo/export-testing-276',
#  'luca0621/multi-RLHF-processed-dataset', 'dakopi/arithmetic__add_sub_multiple',
#  'XAT928/dataset_jiji1', 'masa-ok/Tourism_QA_dataset',
#  'RyanYr/self-reflect_mini8Bit-t0_mistlarge-t12_om2-3_binlabel',
#  'violetxi/NUMINA-V2-Clean-Blocks-10000_10500-200_205',
#  'Moatasem444/arabic-wong-kar-wai-BLIP-captions', 'ksai863423/finetuning_demo',
#  'growth-cadet/jobpost-2-signals_orpo_alignment_completionv2',
#  'SadatHossain01/NLGraph-Raw', 'khushwant04/student_vision',
#  'jfcalvo/export-testing-277', 'MaxBSm/Clasificacion_pantalon_polera',
#  'Moatasem444/arabic-magic-card-captions',
#  'RyanYr/self-reflect_mini8Bit-t0_mistlarge-t12_om2-200k_binlabel',
#  'ValerianFourel/VAEsSOC', 'junnystateofmind/multi-RLHF-65000_turn_0_ckp',
#  'RyanYr/self-reflect_mini8Bit-t0_mistlarge-t12_om2-200k_binlabel_reflection',
#  'RyanYr/self-reflect_mini8Bit-t0_mistlarge-t12_om2-200k_binlabel_correction',
#  'kotyKD/claude-data-sharegpt', 'ziyu3141/rich_feedback_test',
#  'luca0621/multi-RLHF-10000-processed-dataset', 'NexIAlab/chroma',
#  'mlfoundations-dev/alpaca_scale_x2',
#  'MinaMila/CFA_adult_train_ImpFeat_withsex',
#  'MinaMila/adult_test_ImpFeat_withsex', 'plaguss/test_math_shepherd_prm_5',
#  'Gaoj124/china_train_version_1', 'kotyKD/claude-data',
#  'quanshiyun/tokenizer_train_zh', 'ShukaiGong/satellite-image-sichuan',
#  'MinaMila/adult_train_withsex', 'MinaMila/adult_test_withsex',
#  'sebgrima/pb-benchmark', 'DongfuJiang/eval',
#  'MinaMila/adult_train_ImpFeat_withsex', 'cpa2001/alignbot-dataset',
#  'kavanamk/LOLA', 'trnghuybru/resume_llms', 'Gaoj124/china_energy_dataset_1',
#  'Alapan/MTL-Llama3-8b-Instruct-1.2', 'abaowei/k3s',
#  'open-llm-leaderboard/jeffmeloy__jeffmeloy_Qwen2.5-7B-minperplexity-1-details',
#  'Lavador/Vocal_AI', 'Tryzent/Electrostaticsdataset', 'jdmska/my_tsv_corpus',
#  'trnghuybru/data_llm_train', 'liuzzyg/final-filtered-privsyn-data-dp10',
#  'haggs/dhaggerty-dataset-4214', 'rahul77/LaTeX17',
#  'jarredparrett/FOURSQUARE_OPEN_SOURCE_PLACES_x_OVERTURE_INNER_JOIN',
#  'violetxi/NUMINA-V2-Clean-Blocks-9500_10000-16_200', 'Ayushnangia/SynWOZ',
#  'khanhromvn/atri-qa', 'taro3007/prompt_optimization_and_creation',
#  'violetxi/NUMINA-V2-Clean-Blocks-9500_10000-400_500',
#  'IAMTHEMUSIC/newest-data', 'Asap7772/elix_eval_4shot',
#  'Asap7772/hh_eval_4shot', 'Asap7772/hh_persona_eval_4shot',
#  'qq8933/OpenLongCoT-SFT-v2-filtered', 'Fujianhanfei/Classified_images',
#  'taronklm/optimization_and_creation',
#  'krowiemlekommm/Animation_splits_stratified',
#  'violetxi/NUMINA-V2-Clean-Blocks-10500_11000-0_50',
#  'Asap7772/elix_persona_eval_4shot', 'Asap7772/hh_length_eval_4shot',
#  'mlgawd/rejected_dpo', 'Asap7772/hh_length_persona_eval_4shot',
#  'violetxi/NUMINA-V2-Clean-Blocks-9500_10000-206_400',
#  'SHASWATSINGH3101/bail-Pre-training_V1', 'mlgawd/accepted_dpo',
#  'tii-audio/meld_eval', 'Ibbi02/genai-project-dataset-without-trigger-10-test',
#  'HoangVuSnape/TDTU_QA_v1', 'neoneye/simon-arc-combine-v208',
#  'developerZoyal/drugs_stop_use_data',
#  'gokulsrinivasagan/processed_book_corpus-ld', 'jsulz/jsulz',
#  'juantollo/tp_nlp_filtered', 'dhruvnathawani/claude-filter',
#  'aman-augurs/abccc', 'Infernaught/image_tests', 'haggs/dhaggerty-dataset-1763',
#  'macavaney/trec-cast-files', 'haggs/dhaggerty-dataset-2214',
#  'Asap7772/hh_length_persona_eval_4shot_llama-part1-of-1',
#  'Asap7772/hh_length_eval_4shot_llama-part1-of-1',
#  'haggs/dhaggerty-dataset-6958', 'bimbom1310/LawData2024',
#  'Asap7772/hh_length_persona_eval_4shot_prefft-part1-of-1',
#  'Asap7772/hh_length_persona_eval_4shot_ipo-part1-of-1',
#  'Asap7772/hh_length_eval_4shot_ipo-part1-of-1',
#  'Asap7772/hh_length_eval_4shot_prefft-part1-of-1',
#  'sseilene/N4-model-performance', 'haggs/dhaggerty-dataset-1515',
#  'Blexus/pixels_5x5-color', 'Lipsrow/ruwiki_cleaned',
#  'Asap7772/elix_eval_4shot_llama-part1-of-1',
#  'Asap7772/elix_persona_eval_4shot_llama-part1-of-1', 'funlab/homer-uniqmaps',
#  'ziyu3141/rich_feedback_test_new', 'epchannel/Dataset_HUMG',
#  'Blexus/pixels_64x64-color', 'Asap7772/elix_eval_4shot_ipo-part1-of-1',
#  'open-llm-leaderboard/ehristoforu__SoRu-0009-details',
#  'Asap7772/elix_eval_4shot_prefft-part1-of-1',
#  'Asap7772/elix_persona_eval_4shot_prefft-part1-of-1',
#  'Asap7772/elix_persona_eval_4shot_ipo-part1-of-1',
#  'Samoed/WikipediaRetrievalMultilingual',
#  'mlfoundations-dev/webinstruct_stage_1_3', 'razaque/dataset',
#  'sseilene/M4-performance-xl', 'beddi/fake_1K_people_input_output_instruction',
#  'open-llm-leaderboard/Josephgflowers__Tinyllama-STEM-Cinder-Agent-v1-details',
#  'LongVILA/longvila_sft_dataset', 'LongVILA/slimpajama_encode_qwen2_64k',
#  'LongVILA/slimpajama_encode_qwen2_256k',
#  'LongVILA/slimpajama_encode_qwen2_512k', 'LongVILA/slimpajama_encode_qwen2_1M',
#  'AnnGull/GeoWiki', 'Rezwan9463/Janani_AI', 'allenai/pixmo-pointing',
#  'allenai/points', 'mteb/WikipediaRetrievalMultilingual', 'GleghornLab/GO',
#  'alecccdd/wmr', 'willd98/CLOFAI', 'ziyu3141/rich_feedback_dev_new',
#  'FrancophonIA/Ministry_Development_Funds_Regional_Policy',
#  'FrancophonIA/COVID-19_Federal_Public_Service', 'gdurkin/s1_2_nlcd',
#  'FrancophonIA/COVID-19_PIO-CY', 'FrancophonIA/COVID-19_POLISH-GOVv2',
#  'FrancophonIA/COVID-19_ROM-GOV', 'armaggheddon97/lego_minifigure_captions',
#  'mshad2345/MPFBench',
#  'FrancophonIA/COVID-19_Foreign_Affairs_Belgian_government',
#  'patrikgerard/measuring-hate-speech', 'FrancophonIA/COVID-19_Luxembourg',
#  'FrancophonIA/COVID-19_GOV-LUX', 'metalure/171k_bluesky_threads',
#  'FrancophonIA/COVID-19_GEMR_UNESCO', 'neoneye/simon-arc-combine-v209',
#  'Takenoko3333/danbooru-artist', 'Znreza/HONEST-RACE-RELIGION-AND-COUNTERFACTS',
#  'FrancophonIA/COVID-19_OSHA-EUROPA', 'GeiserX/jw-instruct',
#  'FrancophonIA/COVID-19_WIPO', 'FrancophonIA/COVID-19_EI', 'oodeh/eco-gotests',
#  'open-llm-leaderboard/cpayne1303__cp2024-instruct-details',
#  'jonghyunlee/ZINC15', 'manalberrr/DS', 'eliasfiz/rlhf_training_dataset_idx1',
#  'FrancophonIA/COVID-19_SST-DK',
#  'mlfoundations-dev/evol_instruct_gpt-4o-mini_scale_x2',
#  'FrancophonIA/COVID-19_landlaeknir', 'Lucifer484/myDataset',
#  'FrancophonIA/COVID-19_Line_1177_Sweden', 'farisfarisan/qna_lansia_indonesia',
#  'FrancophonIA/COVID-19_Health_Service_Executive_Ireland',
#  'Asap7772/elix_zero_shot_eval', 'Asap7772/hh_length_zero_shot_eval',
#  'FrancophonIA/Human-reviewed_automatic_English_translations_Europeana',
#  'Asap7772/elix_zero_shot_eval_llama-part1-of-1',
#  'Newvel/narrativeqa_filtered_unique_tokenized', 'asdqwde/asdfaf',
#  'v1ctor10/PCA_features_from_SAE', 'ziyu3141/rich_feedback_test_new_1',
#  'DavesArmoury/not_a_robot', 'allenai/pixmo-count',
#  'Asap7772/hh_length_zero_shot_eval_llama-part1-of-1',
#  'ziyu3141/rich_feedback_test_new_2', 'Lachter0808/orya',
#  'juliadollis/Qwen2.5-7B-Instruct_toxigen-data-test_fewshot',
#  'amuvarma/ultrachat-50k', 'ziyu3141/rich_feedback_test_new_3',
#  'clawdelu/deea-v3-shuffled', 'Luca207/synthetic_field', 'flopml/toy-datasets',
#  'RylanSchaeffer/collapse_gemma-2-27b_hs2_accumulate_iter3_sftsd0_temp1_max_seq_len512',
#  'amuvarma/ultrachat-50k-text', 'amuvarma/ultrachat-25k-text',
#  'amuvarma/ultrachat-25k-audio',
#  'RylanSchaeffer/collapse_gemma-2-27b_hs2_accumulate_iter3_sftsd2_temp1_max_seq_len512',
#  'ziyu3141/rich_feedback_test_new_4',
#  'mlfoundations-dev/opengpt_gpt-4o-mini_scale_x2', 'razaque/Processed_dataset',
#  'amuvarma/ultrachat-25k-text-processed', 'hhua2/CompositionCap',
#  'dineshyv/llamastack-traces', 'mlfoundations-dev/opengpt_gpt-4o-mini_scale_x4',
#  'mattlbeck/newsfeeds', 'ziyu3141/rich_feedback_test_new_5',
#  'open-llm-leaderboard/CultriX__SeQwence-14Bv3-details',
#  'patrickfleith/selfinstruct_demo', 'wenceslai/hh-generated_flan_t5_large',
#  'mlfoundations-dev/opengpt_gpt-4o-mini_scale_x8',
#  'juliadollis/Qwen2.5-7B-Instruct_toxigen-data-test_fewshot_limiar2',
#  'rvanova/harness-docfinqa', 'hrizzz/test', 'ziyu3141/rich_feedback_test_new_6',
#  'juliadollis/Qwen2.5-7B-Instruct_toxigen-data-test_fewshot_maior',
#  'Lavador/Vocal_AE', 'ziyu3141/rich_feedback_test_new_7', 'LunarMartins/vozuwu',
#  'ziyu3141/rich_feedback_test_new_8',
#  'product-science/xlam-function-calling-60k-raw',
#  'bgonzalezbustamante/toxicity-Constitution-ES',
#  'juliadollis/Qwen2.5-7B-Instruct_toxigen-data-test_fewshot_maior_LIMIAR3',
#  'juliadollis/Qwen2.5-7B-Instruct_toxigen-data-test_ZEROSHOTMAIOR',
#  'ziyu3141/rich_feedback_test_new_9', 'neoneye/simon-arc-combine-v210',
#  'trnghuybru/cv_llm', 'amuvarma/ultrachat-25k-audio-flattened',
#  'amuvarma/ultrachat-25k-audio-flattened-dev',
#  'hunarbatra/PiXLLaVA-finetune-665k-roi',
#  'hunarbatra/PiXLLaVA-pretrain-558k-roi', 'sarahpann/formatted_help_steer_2',
#  'ziyu3141/rich_feedback_test_new_10',
#  'afrenkai/WPI-Historical-Image-Collection', 'ai2-adapt-dev/math_styled',
#  'amuvarma/ultrachat-25k-audio-speech', 'ziyu3141/rich_feedback_test_new_11',
#  'KurisuTL/paired_data', 'amuvarma/ultrachat-3k-audio-speech',
#  'OreoAu/Creolemorris', 'ziyu3141/rich_feedback_test_new_12',
#  'haggs/test-dataset-561', 'qfq/train_rawcot', 'haggs/test-dataset-9762',
#  'mansurealism/wiki_preprocessed', 'Muadil/openai_summary_comparisons',
#  'violetxi/NUMINA-V2-Clean-Blocks-1800_2000-105_200',
#  'ai2-adapt-dev/gsm8k_messages', 'ben4mn/graphical',
#  'ziyu3141/rich_feedback_test_new_13', 'paskef/finetuning_demo',
#  'junnystateofmind/multi-RLHF-65000_turn_1_ckp',
#  'ziyu3141/rich_feedback_test_new_14', 'EmanuelNovelo/football-players-DB',
#  'open-llm-leaderboard/TinyLlama__TinyLlama-1.1B-intermediate-step-1431k-3T-details',
#  'crazyjeannot/fr_literary_dataset_large',
#  'ai2-adapt-dev/gsm8k_tulu_3_sft_rs_verified',
# ...
#  'PJMixers-Dev/Mielikki_Erebus-87k-axo',
#  'lightblue/rag_datasets_selected_14Bscored', 'dreamyou/ta',
#  'PJMixers-Dev/NyxKrage_asstr-122k-axo',
#  'RyanYr/reflect_mini8bSFTt2-t02_mini8BSFTDPOt1-t1_om2_binlabel',
#  'karimmerchaoui/indian_food_images',
#  'openpecha/style-classification-woodblock',
#  'openpecha/style-classification-manuscript', 'asoria/docling_sample_pdf',
#  'milesway6/test2', 'vedikap11/school_projj', 'pyrihtm/T-SAD2',
#  'MartinElMolon/pln_dataset_frases_ordenadas',
#  'BilalHaneef/Karachi-University-Prospectus', 'lazik/jenny-tts-tags-6h-v1',
#  'lazik/jenny-tts-text-tags-6h-v1', 'Fartilicious/custom_movies_dataset',
#  'kuldeep1408/Box', 'Aeternil/wisc_bc', 'clembench-playpen/kto_small',
#  'nlee-208/gqa_xling', 'juliadollis/treinomestre_pag1a5x15_motivadorasnormais2',
#  'vicky1428/web3crypto', 'openpecha/OCR-Durtsa', 'Deeks090/bus-llama2-7k',
#  'datacomp/imagenet-1k-random-50.0-frac-1over4',
#  'DLI-Lab/mini_rm_benchmark_for_web_agent', 'HUY2612/vietceleb',
#  'datacomp/imagenet-1k-random-30.0-frac-1over4',
#  'lgumpina/akamai-etp-samples_2',
#  'datacomp/imagenet-1k-random-70.0-frac-1over4', 'AlexKarap/DATASET_ASYLUM_NEW',
#  'Deeks090/bus-llama2-9k', 'datacomp/imagenet-1k-random-100.0-frac-1over4',
#  'Bakamol/RPDs', 'NickoSELI/indian_food_images_mock2',
#  'datacomp/imagenet-1k-random-80.0-frac-1over4', 'newbienewbie/test3',
#  'juliadollis/treinomestre_pag1a5x15_detalhistas_curtas',
#  'aitianci/NrB3WIfuDU1pH1rx64', 'ThodorisKoukop/fbb_laydowns_experiments',
#  'RASMUS/dibt10k', 'datacomp/imagenet-1k-random-60.0-frac-1over4',
#  'OpZest/mufimap-test-v1.0', 'ziyadkomakkal/dataset',
#  'aitianci/_jJR09h522g4pSaa64', 'twodgirl/all-attention-on-sd3.5',
#  'xinxinmao/AudioRecord', 'moemoemoe/dbQhN-Al1RiaVffD64', 'BeratGuner00/Borsa',
#  'tfrere/contents', 'max-long/textile_glossaries_and_pile_ner',
#  'Edanur02/MedTurkQuAD', 'sumuks/fairytales_single_shot_questions',
#  'Tobius/8dc2c7db-5470-4169-9f96-288dcc1e9510', 'AlexKarap/ASYLO_DATASET_NEW',
#  'Krainmann/Data_for_cross_bilingual_training', 'harshad317/short_description',
#  'Hahad14/astro_cov', 'harshad317/long_description', 'MLgma/data',
#  'dpatt/jj-credentialing-data', 'moemoemoe/vCRGxoZ_8WzKi32Y43',
#  'oceanpty/Self-J-score-w-ref-skywork-pref-ref-lla31-70b-inst-model-lla-31-8b-inst-thre-0',
#  'jeongseokoh/GSM8K-Contrast-withNegPool', 'Hahad14/astro_data',
#  'RichardErkhov/LSUN', 'zwhe99/aime24',
#  'juliadollis/treinomestre_pag1a5x25_detalhistas2',
#  'LuckyLukke/NEGOTIO_evaluate_evaluator_8B_2',
#  'nikichyy/softwaresentimentanalysis', 'feedbackagent/llama3_8b_reflection1',
#  'JackLeoop/X9jvDXZBtTywTZrS86', 'feedbackagent/llama3_8b_reflection2',
#  'ccop/aloha_stationary_replay_test_v2', 'JackLeoop/dAqKrU-9xtbDVW2z86',
#  'jg3912/ball-type', 'fengxuanbin/swinbert', 'camilaslz/VOZMEGA',
#  'RichardErkhov/VGGHead', 'datacomp/imagenet-1k-random-50.0-frac-1over8',
#  'Duckets/Llamabot2.4', 'MinfengHong/speech-dialogue5', 'thexdk/wiki_en',
#  'moemoemoe/6SxjEDSULxrmy0rR86', 'datacomp/imagenet-1k-random-30.0-frac-1over8',
#  'datacomp/imagenet-1k-random-70.0-frac-1over8', 'WpythonW/RemoveBG',
#  'vietanh0802/ielts-evaluations-simple-ds',
#  'datacomp/imagenet-1k-random-100.0-frac-1over8',
#  'mathreward/8b_llama3_2epoch_selfcorr_horizon2_tmp1',
#  'mathreward/8b_llama3_2epoch_selfcorr_horizon2_tmp07',
#  'datacomp/imagenet-1k-random-80.0-frac-1over8', 'khalidalt/distilabel-example',
#  'juliadollis/treinomestre_pag1a5x20_perguntasmaiores',
#  'JackLeoop/pSHnP2ycoaelKHZ643', 'rblacha/FinetuningRAGROS2',
#  'DrTailor/pt_finetuning_data_conv_processed',
#  'mathreward/8b_llama3_original_selfcorr_horizon2_tmp07',
#  'datacomp/imagenet-1k-random-60.0-frac-1over8',
#  'Orbina-development/tgrt-podcast_tr_related-check',
#  'RyanYr/self-reflect_mini8Bit-t02_llama8B-sft-t1_om2-1', 'hassanjbara/AI4MARS',
#  'datacomp/imagenet-1k-random-50.0-frac-1over16',
#  'feedbackagent/reflection_n16',
#  'mathreward/8b_llama3_original_selfcorr_horizon2_tmp10',
#  'mobilealohafalkenberg/toast_extended',
#  'datacomp/imagenet-1k-random-30.0-frac-1over16',
#  'RyanYr/self-reflect_mini8Bit-t02_llama8B-sft-t1_om2-1_binlabel',
#  'datacomp/imagenet-1k-random-70.0-frac-1over16', 'ahmetkasif/fish',
#  'datacomp/imagenet-1k-random-100.0-frac-1over16',
#  'cobrayyxx/indo-eng_speech_translation_datasets',
#  'datacomp/imagenet-1k-random-50.0-frac-1over32',
#  'datacomp/imagenet-1k-random-80.0-frac-1over16', 'zaidawan/dataset',
#  'ThomasSchwarzmann/erfassung_dataset_01', 'DNA-LLM/generated_seqs',
#  'DrTailor/pt_finetuning_data_qa_batch1',
#  'datacomp/imagenet-1k-random-30.0-frac-1over32',
#  'bwang0911/word-orders-triplet',
#  'datacomp/imagenet-1k-random-50.0-frac-1over64',
#  'datacomp/imagenet-1k-random-70.0-frac-1over32',
#  'datacomp/imagenet-1k-random-100.0-frac-1over32', 'zaidawan/synthetic_agents',
#  'datacomp/imagenet-1k-random-30.0-frac-1over64',
#  'datacomp/imagenet-1k-random-60.0-frac-1over16', 'RobberMJ/111',
#  'ryusangwon/qsaf_answer_only', 'datacomp/imagenet-1k-random-70.0-frac-1over64',
#  'SHASWATSINGH3101/key_info_bail_para_prompts_TRAIN_V1_JSONL',
#  'DrTailor/pt_finetuning_data_qa_code', 'JackLeoop/hgq093oS_bZnZcig43',
#  'MLsheenu/domain_specific_chatbot_dataset',
#  'datacomp/imagenet-1k-random-80.0-frac-1over32',
#  'embodied-ai/close_phone_packing_box',
#  'juliadollis/treinomestre_pag5a10x25_detalhistas',
#  'datacomp/imagenet-1k-random-100.0-frac-1over64', 'sleeping-ai/Moscow-Mule',
#  'juliadollis/treinomestre_pag1a5x20_motivadoraslista',
#  'alleina/Real-Estate-Property-Image-Dataset-Lamudi-Facebook-Ohmyhome-PerchanceAI',
#  'DNA-LLM/train_generated_seq', 'datacomp/imagenet-1k-random-80.0-frac-1over64',
#  'open-llm-leaderboard/Corianas__Neural-Mistral-7B-details',
#  'DrTailor/pt_finetuning_data_qa_batch1_processed',
#  'leezythu/focusllm_train_data', 'ccop/aloha_stationary_replay_test_v3',
#  'datacomp/imagenet-1k-random-60.0-frac-1over32', 'luker42/dataset-1',
#  'QiGuaiOu/so101_test', 'CodeBlackwell/d3_viz_generation',
#  'juliadollis/treinomestre_pag5a10x15_detalhistas_curtas',
#  'moemoemoe/8pQh1oKU-EeEoYxz64', 'opendiffusionai/2b-clothingandfashion',
#  'datacomp/imagenet-1k-random-60.0-frac-1over64', 'mahadev1234/musicart',
#  'lianghsun/tw-administrative-rule', 'RiTA-nlp/itaeval-results',
#  'RobberMJ/tupac', 'thers2m/rijksmuseum_painting_dataset',
#  'ahn1376/bdd100K_test', 'abhiyanta/testing_dataset',
#  'BlackMagii/Qwen_2.5_0.5B-Finetuned-Tokenized-Dataset',
#  'richmondsin/arc_ml_results',
#  'THE-SUPER-MACHINE-GOD-THEORY/99K-SEX-GODDESS-SUPER-FREAK', 'wcyat/shikoto',
#  'phanerozoic/Coq-HoTT-QA', 'embodied-ai/close_phone_packing_box_end_effector',
#  'richmondsin/truthfulqa_ml_mc1_results',
#  'colinhorger/esm2_t30_150M_UR50D_embeddings_temp', 'ArbaazBeg/cytologia',
#  'GoldenGold/wk47sLT60C6EM2jD43', 'erickfmm/OpenLongCoT-Pretrain-ES',
#  'wcyat/shikoto-sweet', 'pxyyy/rlhflow_mixture_scalebio_sampled-nolisa-250k',
#  'HanningZhang/Yesno-Mistral-ORM',
#  'colinhorger/esm2_t33_650M_UR50D_embeddings_temp',
#  'richmondsin/mmlu_ru_results', 'Naozumi0512/g2p-Cantonese-aggregate-pos-retag',
#  'colinhorger/random_embeddings_temp', 'wcyat/shikoto-cantonese',
#  'richmondsin/truthfulqa_ml_mc2_results',
#  'colinhorger/random_esm_embeddings_temp', 'sicheng1806/New-energy-power-plant',
#  'occiglot/arcX', '1rsh/SPInO-BankingDemo-MTQA',
#  'colinhorger/CAMP_exp_embeddings_temp', 'benjamin/flanv2_subsample',
#  'wcyat/shikoto-swc', 'yosrissa/AITA-posts-topics-dataset',
#  'ubowang/embedded_corpus_1207', 'yxnd150150/uieb_llm',
#  'colinhorger/ankh_base_encoder_embeddings_temp', 'richmondsin/mmlu_es_results',
#  'Nash-pAnDiTa/Moamn-75zYk4zhB2c',
#  'DrTailor/pt_finetuning_data_qa_code_processed', 'cppmai/cdip_100k',
#  'lunahr/dolly-15k-gemma2-templated',
#  'happyme531/classical-chinese-poetry-benchmark-70', 'PeterJinGo/math',
#  'Edanur02/MedTurkQuAD_Medical_Turkish_QADataset',
#  'GoldenGold/_xbMti1k1Rbc8cEE64',
#  'brahmairesearch/OpenHermes-2.5-Formatted-OpenAI-Compatible',
#  'DrTailor/pt_finetuning_data_qa_batch2', 'wcyat/shikoto-cantonese-sweet',
#  'cchoi1/pylint_200_hints', 'DrTailor/pt_finetuning_data_qa_batch2_processed',
#  'mlfoundations-dev/oh_v1.2_slim_orca_x2', 'philbutler/so100_test',
#  'JackLeoop/mjxIoNNzAJKFJ4QS64', 'andronov/sprites',
#  'mlfoundations-dev/oh_v1.2_unnatural_instructions_x.125',
#  'richmondsin/mmlu_id_results', 'ilpa-user/nc_mp3_V3', 'AhmedBadawy11/UAE18000',
#  'Erland/rlaif-v-sample-non-processed', 'richmondsin/hellaswag_ca_results',
#  'GoldenGold/UePsHMFvkyU7-YSg64', 'niki2one/dataset_kiaraV5',
#  'mlfoundations-dev/oh_v1.2_unnatural_instructions_x.25',
#  'juliadollis/treinomestre_pag5a10x20_motivadoraslista', 'Utsav2001/Feedback',
#  'siala94/amsterdam-updated',
#  'BlackMagii/SmolLM-360M-Finetuned-Tokenized-Dataset',
#  'anastasiafrosted/endpoint_stats', 'GoldenGold/_dDUb2Sk04HBI1FK86',
#  'MikeGreen2710/smoothed_all_df_1600_1700',
#  'MikeGreen2710/smoothed_all_df_1700_1800',
#  'HaninZ/edinburghcstr_ami_test_embeddings', 'ppaper/origin',
#  'mlfoundations-dev/oh_v1.2_unnatural_instructions_x.5',
#  'HaninZ/gilkeyio_inclusive_voice_test_embeddings',
#  'HaninZ/janaab_supreme-court-speech_test_embeddings',
#  'HaninZ/joefox_LibriSpeech_test_noise_test_embeddings',
#  'HaninZ/Jzuluaga_atcosim_corpus_test_embeddings',
#  'RichardErkhov/The_Million_Song_Dataset',
#  'HaninZ/MWilinski_snips_slu_v1.0_train_embeddings',
#  'HaninZ/Na0s_Primock_med_test_embeddings', 'cchoi1/pylint_200_hints_location',
#  'HaninZ/libri_transcripts_text_embeddings', 'JackLeoop/92GSwRlmRE96i3EJ64',
#  'chaseharmon/6.7960_Shakespeare', 'chenrm/webnovel-bilibili',
#  'chaseharmon/6.7960_Slang',
#  'mlfoundations-dev/oh_v1.2_unnatural_instructions_x2',
#  'Deepri24/Thirukural_EnglishMeaning_Updated.csv',
#  'open-llm-leaderboard/nvidia__Hymba-1.5B-Base-details',
#  'chenrm/webnovel-ciweimao', 'hsa1155/my_toxic_data',
#  'open-llm-leaderboard/nvidia__Hymba-1.5B-Instruct-details',
#  'richmondsin/mmlu_ca_results',
#  'accelerated-komputing/size_of_all_possible_scans_10_patients',
#  'chenrm/webnovel-boluobao', 'DuongTrongChi/cmcu_data',
#  'mlfoundations-dev/oh_v1.2_unnatural_instructions_x4',
#  'yxnd150150/uieb_llm_v2', 'ram43/guanaco-llama2-1k',
#  'magic-mirror/galgame-dialogue', 'RichardErkhov/dhcp_fmri_pipeline',
#  'drkvcsstvn/smearshare_cumulative_distribution', 'eysahdne/hULngtv0WDHun9Or64',
#  'WMRNORDIC/swedish-telephonic-dataset', 'babs/play-ht-w-phonemes',
#  'Wen0001/koch_test', 'teofeliu/doc-handwriting-extraction-1',
#  'prithvi3/filtered_forecast_sample_test',
#  'skdrx/python-dpo-dataset-complete-just-formatting',
#  'richmondsin/mmlu_mr_results', 'amuvarma/voice-assistant-10k-processed-1',
#  'BrunoHays/test-push-remove', 'Honi086/voz_theweeknd', 'thexdk/wiki_ru',
#  'GoldenGold/J6mwRgL5mE5da_kG64',
#  'embodied-ai/remove_small_envelope_from_big_end_effector',
#  'cchoi1/agentless_pylint_200', 'chenrm/yyets-subtitles',
#  'juliadollis/treinomestre_pag5a10x12_motivadorasegrandes',
#  'rnjs1992/active-llm-datasets_acquired_dataset_random_budget50000',
#  'rnjs1992/active-llm-datasets_acquired_dataset_confidence_budget50000',
#  'rnjs1992/active-llm-datasets_acquired_dataset_entropy_budget25000',
#  'rnjs1992/active-llm-datasets_acquired_dataset_random_budget25000',
#  'rnjs1992/active-llm-datasets_acquired_dataset_entropy_budget50000',
#  'rnjs1992/active-llm-datasets_acquired_dataset_confidence_budget25000',
#  'aitianci/bAL-QGEpZxI_rwzi64',
#  'juliadollis/treinomestre_pag10a20x20_motivadoraslista',
#  'amuvarma/10k-tune-audio-text_answer',
#  'mlfoundations-dev/airoboros_stage_1_gpt-4o-mini_v1_3',
#  'open-llm-leaderboard/allknowingroger__Gemma2Slerp2-2.6B-details',
#  'JackLeoop/YgwsNcOMKyQTVBKS86', 'feedbackagent/llama3_8b_math_test',
#  'BluewhaleSec/General-Level_functions-Code', 'glenng/temporal_drive',
#  'raft-security-lab/safe_unsecure_output',
#  'keivalya/arm-manipulation-behavior-cloning',
#  'andreaparker/wiki-ss-nq-train-overlap-sm',
#  'mlfoundations-dev/airoboros_stage_2_gpt-4o-mini_v1_3',
#  'open-llm-leaderboard/allknowingroger__Gemma2Slerp1-2.6B-details',
#  'dataai1205/cohere_dataset_third', 'amuvarma/audio-in-out-10k_part1',
#  'amuvarma/audio-in-out-10k_part2',
#  'open-llm-leaderboard/allknowingroger__QwenSlerp6-14B-details',
#  'juliadollis/treinomestre_pag5a10x25_motivadorasnormais',
#  'pablovela5620/gradio-rerun-0.0.9',
#  'embodied-ai/stack_small_envelope_on_big_end_effector',
#  'philbutler/green_ball_red_cup-10sec_10ep',
#  'amuvarma/audio-in-out-10k_part1-1dups-contentonly',
#  'open-llm-leaderboard/allknowingroger__QwenSlerp5-14B-details',
#  'andreaparker/wiki-ss-nq-train-overlap-strict-sm', 'DSWF/conversation-dataset',
#  'DSWF/movie-dataset',
#  'open-llm-leaderboard/allknowingroger__QwenSlerp4-14B-details',
#  'dielinke/legal-knowledge', 'moemoemoe/dambGrBP7uyKiun964',
#  'embodied-ai/insert_small_enevelope_inside_big_end_effector',
#  'pooya-davoodi-parasail/openai_records_c5194e16', 'carpinamz/backff',
#  'amuvarma/10k-audio-audio-contentonly',
#  'mlfoundations-dev/airoboros_stage_3_gpt-4o-mini_v1_3',
#  'sumuks/fairytales_single_shot_questions_4o_mini_v2',
#  'embodied-ai/remove_phone_from_envelope_end_effector',
#  'pooya-davoodi-parasail/openai_records_2e9b317a', 'Moreza009/triplet_smiles',
#  'pooya-davoodi-parasail/openai_records_a122394e',
#  'moemoemoe/oD2obJuaZgHrBaA164', 'nielsr/gemini-results-2024-11-29',
#  'open-llm-leaderboard/allknowingroger__QwenStock2-14B-details',
#  'open-llm-leaderboard/allknowingroger__QwenStock1-14B-details',
#  'sidleal/NURC-SP_Corpus_Minimo', 'cornstack/cornstack-ruby-v1',
#  'pooya-davoodi-parasail/openai_records_341679a6',
#  'open-llm-leaderboard/allknowingroger__QwenStock3-14B-details',
#  'pooya-davoodi-parasail/openai_records_3bc778cf',
#  'RyanYr/reflect_mini8bSFTt2-t02_mini8BSFTDPOt1-t1_om2_ref', 'htlou/CoRe_train',
#  'andreaparker/wiki-ss-nq-overlapping', 'moemoemoe/1z8D8rhGsVx9bHPn107',
#  'richmondsin/mmlu_ml_results', 'fxwang/llama-8B-easy-math-trees_v2-round-1',
#  'andreaparker/wiki-ss-nq-1000-only',
#  'PJMixers-Dev/allura-org_fujin-cleaned-stage-2-axo',
#  'PJMixers-Dev/winglian_visual-novels-json-axo',
#  'PJMixers-Dev/allura-org_r_shortstories_24k-axo',
#  'PJMixers-Dev/KaraKaraWitch_AnimeSubtitle-axo', 'SuzieD/A1',
#  'ZhangShenao/iterative-gsm-iter1', 'ivrejchik/medmcqa-instruction',
#  'ivrejchik/medmcqa-benchmark', 'Bharatdeep-H/multi-lingual-classification-v0',
#  'ApricotWine/CMIN-US-binary', 'dannylee1020/open-preference',
#  'RyanYr/reflect_mini8bSFTt2-t02_mini8BSFTDPOt1-t1_om2_ref_binlabel',
#  'CanopyLabs/audio_pretrain_10m-facodec', 'eliasfiz/audio_pretrain_10m-facodec',
#  'CanopyElias/audio_pretrain_10m-facodec',
#  'sumuks/fairytales_single_shot_questions_llama70b', 'Stalibr/test_001',
#  'ivrejchik/medmcqa-conversation', 'violetxi/MATH500-SFT-PRM-EVAL-Merged',
#  'EMERGE-lab/GPUDrive_mini', 'jtan4albany/test', 'pajacques/yes',
#  'jasonamilne/adversarial_squad_datasets',
#  'apockill/myarm-6-put-cube-to-the-side-radians', 'richmondsin/mmlu_hi_results',
#  'coderGenMC/active-llm-datasets_acquired_dataset_random_budget50000',
#  'coderGenMC/active-llm-datasets_acquired_dataset_confidence_budget50000',
#  'coderGenMC/active-llm-datasets_acquired_dataset_entropy_budget25000',
#  'Shaagun/Instruction_Lithuanian_English', 'Geraldine/Ead-Instruct-full-20k',
#  'user3984/circuit-cot', 'richmondsin/hellaswag_mr_results',
#  'moemoemoe/eHkW9EQApU9n0IFL64',
#  'sumuks/fairytales_single_shot_questions_llama3_3_70b',
#  'Nash-pAnDiTa/Moamn-33WCC3EtH0E', 'nielsr/gemini-results-2024-12-02',
#  'juliadollis/treinomestre_pag10a20x12_detalhistas',
#  'jealk/scandi-wiki-combined', 'ntnu-smil/lttc-augmented-tts-1',
#  'Bogdan01m/wildguardmix-cleaned', 'Shaagun/Instruc_Lithuanian',
#  'JohnVitz/rustHeaderFiles',
#  'violetxi/Value-v0-MATH500-SFT-PRM-EVAL-Merged-mc128',
#  'aitianci/j2Kr47ey-EmXNKcM86', 'juliadollis/treinomestre_pag10a5x10_novas',
#  'ahn1376/LLM_Tests',
#  'open-llm-leaderboard/allknowingroger__Gemma2Slerp1-27B-details',
#  'open-llm-leaderboard/allknowingroger__GemmaStock1-27B-details',
#  'juliadollis/dataset_prefinal_nlp', 'gp06aug/Face_Bench_Face_Counting',
#  'open-llm-leaderboard/allknowingroger__Gemma2Slerp3-27B-details',
#  'SharanShivram/rustHeaderFiles',
#  'open-llm-leaderboard/allknowingroger__Gemma2Slerp4-27B-details',
#  'open-llm-leaderboard/allknowingroger__Gemma2Slerp2-27B-details',
#  'glenng/temporal_drive_frames', 'moemoemoe/f3E16GTlKl3zBN7G43']

# %% [markdown]
# ---

# %%
from datasets import load_dataset

# Disable split verification by setting ignore_verifications=True
dataset = load_dataset("cnn_dailymail", "3.0.0", ignore_verifications=True)

# Select a small subset for testing
subset = dataset['train'].select(range(15))
print(subset[0])
# Out:
# WARNING:datasets.builder:Using custom data configuration 1.0.0-9039e3832de1dbcc
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/parquet/1.0.0-9039e3832de1dbcc/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1427: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# {'article': 'LONDON, England (Reuters) -- Harry Potter star Daniel Radcliffe gains access to a reported £20 million ($41.1 million) fortune as he turns 18 on Monday, but he insists the money won\'t cast a spell on him. Daniel Radcliffe as Harry Potter in "Harry Potter and the Order of the Phoenix" To the disappointment of gossip columnists around the world, the young actor says he has no plans to fritter his cash away on fast cars, drink and celebrity parties. "I don\'t plan to be one of those people who, as soon as they turn 18, suddenly buy themselves a massive sports car collection or something similar," he told an Australian interviewer earlier this month. "I don\'t think I\'ll be particularly extravagant. "The things I like buying are things that cost about 10 pounds -- books and CDs and DVDs." At 18, Radcliffe will be able to gamble in a casino, buy a drink in a pub or see the horror film "Hostel: Part II," currently six places below his number one movie on the UK box office chart. Details of how he\'ll mark his landmark birthday are under wraps. His agent and publicist had no comment on his plans. "I\'ll definitely have some sort of party," he said in an interview. "Hopefully none of you will be reading about it." Radcliffe\'s earnings from the first five Potter films have been held in a trust fund which he has not been able to touch. Despite his growing fame and riches, the actor says he is keeping his feet firmly on the ground. "People are always looking to say \'kid star goes off the rails,\'" he told reporters last month. "But I try very hard not to go that way because it would be too easy for them." His latest outing as the boy wizard in "Harry Potter and the Order of the Phoenix" is breaking records on both sides of the Atlantic and he will reprise the role in the last two films.  Watch I-Reporter give her review of Potter\'s latest » . There is life beyond Potter, however. The Londoner has filmed a TV movie called "My Boy Jack," about author Rudyard Kipling and his son, due for release later this year. He will also appear in "December Boys," an Australian film about four boys who escape an orphanage. Earlier this year, he made his stage debut playing a tortured teenager in Peter Shaffer\'s "Equus." Meanwhile, he is braced for even closer media scrutiny now that he\'s legally an adult: "I just think I\'m going to be more sort of fair game," he told Reuters. E-mail to a friend . Copyright 2007 Reuters. All rights reserved.This material may not be published, broadcast, rewritten, or redistributed.', 'highlights': "Harry Potter star Daniel Radcliffe gets £20M fortune as he turns 18 Monday . Young actor says he has no plans to fritter his cash away . Radcliffe's earnings from first five Potter films have been held in trust fund .", 'id': '42c027e4ff9730fbb3de84c1af0d2c506e41c3e4'}

# %%
dataset_ = subset
print(dataset_)
# Out:
# Dataset({
#     features: ['article', 'highlights', 'id'],
#     num_rows: 15
# })

# %%
print(f"👉Dataset len(dataset): {len(dataset_)}")
print("\n👉First item 'dataset[0]':")
pprint(dataset_[0])
# Out:
# 👉Dataset len(dataset): 15
#
# 👉First item 'dataset[0]':
# {'article': 'LONDON, England (Reuters) -- Harry Potter star Daniel Radcliffe '
#             'gains access to a reported £20 million ($41.1 million) fortune as '
#             "he turns 18 on Monday, but he insists the money won't cast a "
#             'spell on him. Daniel Radcliffe as Harry Potter in "Harry Potter '
#             'and the Order of the Phoenix" To the disappointment of gossip '
#             'columnists around the world, the young actor says he has no plans '
#             'to fritter his cash away on fast cars, drink and celebrity '
#             'parties. "I don\'t plan to be one of those people who, as soon as '
#             'they turn 18, suddenly buy themselves a massive sports car '
#             'collection or something similar," he told an Australian '
#             'interviewer earlier this month. "I don\'t think I\'ll be '
#             'particularly extravagant. "The things I like buying are things '
#             'that cost about 10 pounds -- books and CDs and DVDs." At 18, '
#             'Radcliffe will be able to gamble in a casino, buy a drink in a '
#             'pub or see the horror film "Hostel: Part II," currently six '
#             'places below his number one movie on the UK box office chart. '
#             "Details of how he'll mark his landmark birthday are under wraps. "
#             'His agent and publicist had no comment on his plans. "I\'ll '
#             'definitely have some sort of party," he said in an interview. '
#             '"Hopefully none of you will be reading about it." Radcliffe\'s '
#             'earnings from the first five Potter films have been held in a '
#             'trust fund which he has not been able to touch. Despite his '
#             'growing fame and riches, the actor says he is keeping his feet '
#             'firmly on the ground. "People are always looking to say \'kid '
#             'star goes off the rails,\'" he told reporters last month. "But I '
#             'try very hard not to go that way because it would be too easy for '
#             'them." His latest outing as the boy wizard in "Harry Potter and '
#             'the Order of the Phoenix" is breaking records on both sides of '
#             'the Atlantic and he will reprise the role in the last two films.  '
#             "Watch I-Reporter give her review of Potter's latest » . There is "
#             'life beyond Potter, however. The Londoner has filmed a TV movie '
#             'called "My Boy Jack," about author Rudyard Kipling and his son, '
#             'due for release later this year. He will also appear in "December '
#             'Boys," an Australian film about four boys who escape an '
#             'orphanage. Earlier this year, he made his stage debut playing a '
#             'tortured teenager in Peter Shaffer\'s "Equus." Meanwhile, he is '
#             "braced for even closer media scrutiny now that he's legally an "
#             'adult: "I just think I\'m going to be more sort of fair game," he '
#             'told Reuters. E-mail to a friend . Copyright 2007 Reuters. All '
#             'rights reserved.This material may not be published, broadcast, '
#             'rewritten, or redistributed.',
#  'highlights': 'Harry Potter star Daniel Radcliffe gets £20M fortune as he '
#                'turns 18 Monday . Young actor says he has no plans to fritter '
#                "his cash away . Radcliffe's earnings from first five Potter "
#                'films have been held in trust fund .',
#  'id': '42c027e4ff9730fbb3de84c1af0d2c506e41c3e4'}

# %% [markdown]
# ---

# %% [markdown]
# ### **BART Fine-Tuning: Using Transformers**

# %%
# Importing librareis
import torch
from torch.nn import functional as F
from torch import nn
import pytorch_lightning as pl

from transformers import BartForConditionalGeneration, BartTokenizer
from sklearn.model_selection import train_test_split
import pandas as pd

from transformers import (
    AdamW,
    get_linear_schedule_with_warmup
)
from torch.utils.data import DataLoader

# %%
# Checking out the GPU we have access to. This is output is from the google colab version.
# !nvidia-smi
# Out:
# Fri Dec  6 21:47:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ---

# %%
import torch
import pandas as pd
import pytorch_lightning as pl
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

class Dataset(torch.utils.data.Dataset):
    """Custom dataset class for text summarization using PyTorch DataLoader.

    For more information about Dataset and DataLoader, see:
    https://pytorch.org/tutorials/beginner/data_loading_tutorial.html
    """

    def __init__(self, texts, summaries, tokenizer, source_len, summ_len):
        """
        Initialize the Dataset.

        Args:
            texts (list): List of input texts.
            summaries (list): List of target summaries.
            tokenizer: Tokenizer for text encoding.
            source_len (int): Maximum length for input text.
            summ_len (int): Maximum length for target summary.
        """
        self.texts = texts
        self.summaries = summaries
        self.tokenizer = tokenizer
        self.source_len = source_len
        self.summ_len = summ_len

    def __len__(self):
        """
        Get the number of samples in the dataset.
        """
        return len(self.summaries) - 1

    def __getitem__(self, index):
        """
        Get a single data sample from the dataset.

        Args:
            index (int): Index of the data sample to retrieve.

        Returns:
            Tuple containing:
            - source input IDs
            - source attention mask
            - target input IDs
            - target attention mask
        """
        text = ' '.join(str(self.texts[index]).split())
        summary = ' '.join(str(self.summaries[index]).split())

        # Article text pre-processing
        source = self.tokenizer.batch_encode_plus([text],
                                                  max_length=self.source_len,
                                                  pad_to_max_length=True,
                                                  return_tensors='pt')
        # Summary Target pre-processing
        target = self.tokenizer.batch_encode_plus([summary],
                                                  max_length=self.summ_len,
                                                  pad_to_max_length=True,
                                                  return_tensors='pt')

        return (
            source['input_ids'].squeeze(),
            source['attention_mask'].squeeze(),
            target['input_ids'].squeeze(),
            target['attention_mask'].squeeze()
        )

class BARTDataLoader(pl.LightningDataModule):
    '''Pytorch Lightning Model Dataloader class for BART'''

    def __init__(self, tokenizer, text_len, summarized_len, file_path,
                 corpus_size, columns_name, train_split_size, batch_size):
        """
        Initialize the BARTDataLoader.

        Args:
            tokenizer: Tokenizer for text encoding.
            text_len (int): Maximum length for input text.
            summarized_len (int): Maximum length for target summary.
            file_path (str): Path to the CSV data file.
            corpus_size (int): Number of rows to read from the CSV file.
            columns_name (list): List of column names to use.
            train_split_size (float): Size of the training split (e.g., 0.8 for 80%).
            batch_size (int): Batch size for data loading.
        """
        super().__init__()
        self.tokenizer = tokenizer
        self.text_len = text_len
        self.summarized_len = summarized_len
        self.input_text_length = summarized_len
        self.file_path = file_path
        self.nrows = corpus_size
        self.columns = columns_name
        self.train_split_size = train_split_size
        self.batch_size = batch_size

    def prepare_data(self):
        """
        Load and preprocess the data from the CSV file.
        """
        data = pd.read_csv(self.file_path, nrows=self.nrows, encoding='latin-1')
        data = data[self.columns]
        data.iloc[:, 1] = 'summarize: ' + data.iloc[:, 1]
        self.text = list(data.iloc[:, 0].values)
        self.summary = list(data.iloc[:, 1].values)

    def setup(self, stage=None):
        """
        Split the data into training and validation sets.

        Args:
            stage (str): The current stage ('fit' or 'test').
        """
        X_train, y_train, X_val, y_val = train_test_split(
            self.text, self.summary, train_size=self.train_split_size
        )

        self.train_dataset = (X_train, y_train)
        self.val_dataset = (X_val, y_val)

    def train_dataloader(self):
        """
        Create a DataLoader for the training dataset.
        """
        train_data = Dataset(texts=self.train_dataset[0],
                             summaries=self.train_dataset[1],
                             tokenizer=self.tokenizer,
                             source_len=self.text_len,
                             summ_len=self.summarized_len)
        return DataLoader(train_data, self.batch_size)

    def val_dataloader(self):
        """
        Create a DataLoader for the validation dataset.
        """
        val_dataset = Dataset(texts=self.val_dataset[0],
                              summaries=self.val_dataset[1],
                              tokenizer=self.tokenizer,
                              source_len=self.text_len,
                              summ_len=self.summarized_len)
        return DataLoader(val_dataset, self.batch_size)

# %%
import torch
import pytorch_lightning as pl
from transformers import AdamW

class AbstractiveSummarizationBARTFineTuning(pl.LightningModule):
    """Abstractive summarization model class for fine-tuning BART."""

    def __init__(self, model, tokenizer):
        """
        Initialize the AbstractiveSummarizationBARTFineTuning model.

        Args:
            model: Pre-trained BART model.
            tokenizer: BART tokenizer.
        """
        super().__init__()
        self.model = model
        self.tokenizer = tokenizer

    def forward(self, input_ids, attention_mask, decoder_input_ids,
                decoder_attention_mask=None, lm_labels=None):
        """
        Forward pass for the model.

        Args:
            input_ids: Input token IDs.
            attention_mask: Attention mask for input.
            decoder_input_ids: Target token IDs.
            decoder_attention_mask: Attention mask for target.
            lm_labels: Language modeling labels.

        Returns:
            Model outputs.
        """
        outputs = self.model.forward(
            input_ids=input_ids,
            attention_mask=attention_mask,
            decoder_input_ids=decoder_input_ids,
            labels=decoder_input_ids
        )

        return outputs

    def preprocess_batch(self, batch):
        """
        Reformat and preprocess the batch for model input.

        Args:
            batch: Batch of data.

        Returns:
            Formatted input and target data.
        """
        input_ids, source_attention_mask, decoder_input_ids, \
        decoder_attention_mask = batch

        y = decoder_input_ids
        decoder_ids = decoder_input_ids
        source_ids = input_ids
        source_mask = source_attention_mask

        return source_ids, source_mask, decoder_ids, decoder_attention_mask, decoder_attention_mask

    def training_step(self, batch, batch_idx):
        """
        Training step for the model.

        Args:
            batch: Batch of training data.
            batch_idx: Index of the batch.

        Returns:
            Loss for the training step.
        """
        input_ids, source_attention_mask, decoder_input_ids, \
        decoder_attention_mask, lm_labels = self.preprocess_batch(batch)

        outputs = self.forward(input_ids=input_ids, attention_mask=source_attention_mask,
                               decoder_input_ids=decoder_input_ids,
                               decoder_attention_mask=decoder_attention_mask,
                               lm_labels=lm_labels
                       )
        loss = outputs.loss

        return loss

    def validation_step(self, batch, batch_idx):
        """
        Validation step for the model.

        Args:
            batch: Batch of validation data.
            batch_idx: Index of the batch.

        Returns:
            Loss for the validation step.
        """
        input_ids, source_attention_mask, decoder_input_ids, \
        decoder_attention_mask, lm_labels = self.preprocess_batch(batch)

        outputs = self.forward(input_ids=input_ids, attention_mask=source_attention_mask,
                               decoder_input_ids=decoder_input_ids,
                               decoder_attention_mask=decoder_attention_mask,
                               lm_labels=lm_labels
                       )
        loss = outputs.loss

        return loss

    def training_epoch_end(self, outputs):
        """
        Calculate and log the average training loss for the epoch.

        Args:
            outputs: List of training step outputs.
        """
        avg_loss = torch.stack([x["loss"] for x in outputs]).mean()
        self.log('Epoch', self.trainer.current_epoch)
        self.log('avg_epoch_loss', {'train': avg_loss})

    def val_epoch_end(self, loss):
        """
        Calculate and log the average validation loss for the epoch.

        Args:
            loss: List of validation step losses.
        """
        avg_loss = torch.stack([x["loss"] for x in loss]).mean()
        self.log('avg_epoch_loss', {'Val': avg_loss})

    def configure_optimizers(self):
        """
        Configure and return the optimizer for the model.

        Returns:
            Optimizer for training.
        """
        model = self.model
        optimizer = AdamW(model.parameters())
        self.opt = optimizer

        return [optimizer]

# %%
# Tokenizer
# Upload the curated_data_subset.csv if using Colab or change the path to a local file
model_ = BartForConditionalGeneration.from_pretrained("facebook/bart-base")
tokenizer = BartTokenizer.from_pretrained("facebook/bart-base")

# Dataloader
# Initialize a DataLoader for processing and loading data
dataloader = BARTDataLoader(tokenizer=tokenizer, text_len=512,
                            summarized_len=150,
                            file_path='/content/curated_data_subset.csv',
                            corpus_size=50, columns_name=['article_content','summary'],
                            train_split_size=0.8, batch_size=2)

# Read and pre-process data
dataloader.prepare_data()

# Train-test Split
# Split the data into training and validation sets
dataloader.setup()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Main Model class
# Create an instance of the AbstractiveSummarizationBARTFineTuning model
model = AbstractiveSummarizationBARTFineTuning(model=model_, tokenizer=tokenizer)

# %%
# Trainer Class
# Initialize a PyTorch Lightning Trainer for training and evaluation
# You can specify the number of GPUs (e.g., gpus=1) if available, or remove it if not.
trainer = pl.Trainer(check_val_every_n_epoch=1, max_epochs=5, gpus=1)

# Fit model
# Train the model using the specified trainer and data loader
trainer.fit(model, dataloader)
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:466: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type                         | Params
# -------------------------------------------------------
# 0 | model | BartForConditionalGeneration | 139 M
# -------------------------------------------------------
# 139 M     Trainable params
# 0         Non-trainable params
# 139 M     Total params
# 557.682   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2339: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/trainer.py:1609: PossibleUserWarning: The number of training batches (5) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:232: UserWarning: You called `self.log('Epoch', ...)` in your `training_epoch_end` but the value needs to be floating point. Converting it to torch.float32.
#   warning_cache.warn(
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=5` reached.

# %% [markdown]
# ---

# %% [markdown]
# # **BART Abstractive Summarization: Using Pre Trained Model**

# %%
from transformers import BartTokenizer, BartForConditionalGeneration, BartConfig

# %%
def summarize_article(article):
    # Load BART model and tokenizer
    model_name = 'facebook/bart-large-cnn'
    tokenizer = BartTokenizer.from_pretrained(model_name)
    model = BartForConditionalGeneration.from_pretrained(model_name)

    # Tokenize and encode the article
    inputs = tokenizer.encode(article, return_tensors='pt', max_length=1024, truncation=True)

    # Generate summary
    summary_ids = model.generate(inputs, num_beams=4, max_length=150, early_stopping=True)
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

    return summary

# Example usage
article = """
My friends are cool but they eat too many carbs.
"""

summary = summarize_article(article)
print("Summary:")
print(summary)
# Out:
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-cnn and are newly initialized: ['model.shared.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Summary:
# My friends are cool but they eat too many carbs. That's what this is all about. I don't want you to think I'm a bad person. I'm not. I just don't like to be around people who eat too much carbs. This is my way of telling you that.

# %%
article = '''Iranâ€™s High Council of Cyberspace, one of the main entities deciding the fate of virtual currencies in Iran, has welcomed the idea of Bitcoin and other cryptocurrencies if they are harnessed by clearly-stated regulations. â€œWe [at the HCC] welcome Bitcoin, but we must have regulations for Bitcoin and any other digital currency. Studies are necessary for considering a new currency,â€ Abolhassan Firouzabadi, HCC secretary, told ILNA. He said HCC and the Central Bank of Iran are currently studying virtual currencies, as they have captured the attention of the world. However, he points out that even though the CBI has yet to devise definitive regulations for Bitcoin and similar currencies, â€œmany in Iran are dealing with Bitcoin, be it purchasing, selling or mining it, and even dealing with it in exchange shops, creating content and establishing startupsâ€. CBI has envisioned six documents on fintechs and cryptocurrencies that will be unveiled by the end of the next fiscal year in March 2019. Two of them, dealing with payment initiators and payment facilitators, have already been published with a third covering micropayments and related technologies in fintech to be announced in the next few weeks. The fifth document exclusively deals with cryptocurrencies and will be unveiled by the time the sixth month of the next fiscal year comes to an end in September 2018. As CBI has announced, it will be a regulatory framework instead of clear-cut regulations. Firouzabadi said Iranâ€™s central bank, like that of many other nations, has not come to a stable and defined stance on Bitcoin, noting that many countries look at it as a potentially dangerous option in light of its violent price fluctuations and investment risk. Less than two weeks ago, the head of CBIâ€™s Innovative Technologies Department, Nasser Hakimi, asked investors and the public to refrain from dealing with virtual currencies without proper knowledge and to remain cautious. â€œMechanisms of control and supervision over the supply of cryptocurrencies are being implemented through the collaboration of the central bank and related entities, but the people must be aware of their risks and dangers on the demand side,â€ he added. Around the same days, Bitcoin had experienced its third steep decline of the year to stoop lower than $6,000 after briefly skyrocketing to around $7,800. In the two weeks since, it reached yet another staggering high of more than $8,300. The cryptocurrency is priced just shy of $8,200 as of this writing, while Iranians can purchase one at roughly 350 million rials ($8,400). The HCC secretary said that in light of the ease of use and anonymity of Bitcoin, high investment profits and lack of any transaction fees, it has emerged as a cataclysmic change in banking and online businesses. â€œOur view regarding Bitcoin is positive, but it does not mean that we will not require regulations in this regard because following the rules is a must,â€ he said. Firouzabadi said he hopes CBIâ€™s stance toward cryptocurrencies will soon be clarified, adding that HCC will continue to conduct studies and evaluate pros and cons of virtual currencies.'''

# %%
summary = summarize_article(article)
print("Summary:")
print(summary)
# Out:
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-cnn and are newly initialized: ['model.shared.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Summary:
# Iran's High Council of Cyberspace has welcomed the idea of Bitcoin and other cryptocurrencies if they are harnessed by clearly-stated regulations. HCC and the Central Bank of Iran are currently studying virtual currencies. CBI has envisioned six documents on fintechs and cryptocurrencies that will be unveiled by the end of the next fiscal year in March 2019.

# %%
# !pip install rouge-score
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)

# %%
from datasets import load_metric

rouge = load_metric("rouge")
ground_truth_summaries = [
    "Iran open to cryptocurrencies, planning new regulationsÂ"
    ]  # Ground truth summaries (highlights)

results = rouge.compute(predictions=[summarize_article(article)], references=ground_truth_summaries)

# Print ROUGE results
print("ROUGE Results:", results)
# Out:
# <ipython-input-24-a1b1af5a2f29>:3: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric("rouge")
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-cnn and are newly initialized: ['model.shared.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ROUGE Results: {'rouge1': AggregateScore(low=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091), mid=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091), high=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091)), 'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)), 'rougeL': AggregateScore(low=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091), mid=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091), high=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091)), 'rougeLsum': AggregateScore(low=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091), mid=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091), high=Score(precision=0.05084745762711865, recall=0.42857142857142855, fmeasure=0.09090909090909091))}

# %% [markdown]
# ---

# %% [markdown]
# # References:
#
# * https://huggingface.co/transformers/model_doc/bart.html
# * https://www.pytorchlightning.ai/
# * https://www.frase.io/blog/20-applications-of-automatic-summarization-in-the-enterprise/
# * https://medium.com/sciforce/towards-automatic-summarization-part-2-abstractive-methods-c424386a65ea
# * https://medium.com/swlh/a-simple-overview-of-rnn-lstm-and-attention-mechanism-9e844763d07b
# * https://github.com/CurationCorp/curation-corpus

# %% [markdown]
# ---

# %% [markdown]
# ## Enhanced Preprocessing

# %%
import re

def clean_text(text):
    # Remove special characters and multiple spaces
    text = re.sub(r'[^a-zA-Z0-9 .,?!]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.lower()

# Example usage
sample_text = "Iranâ€™s High Council of Cyberspace, one of the main entities deciding the fate of virtual currencies in Iran, has welcomed the idea of Bitcoin and other cryptocurrencies if they are harnessed by clearly-stated regulations. â€œWe [at the HCC] welcome Bitcoin, but we must have regulations for Bitcoin and any other digital currency. Studies are necessary for considering a new currency,â€ Abolhassan Firouzabadi, HCC secretary, told ILNA. He said HCC and the Central Bank of Iran are currently studying virtual currencies, as they have captured the attention of the world. However, he points out that even though the CBI has yet to devise definitive regulations for Bitcoin and similar currencies, â€œmany in Iran are dealing with Bitcoin, be it purchasing, selling or mining it, and even dealing with it in exchange shops, creating content and establishing startupsâ€. CBI has envisioned six documents on fintechs and cryptocurrencies that will be unveiled by the end of the next fiscal year in March 2019. Two of them, dealing with payment initiators and payment facilitators, have already been published with a third covering micropayments and related technologies in fintech to be announced in the next few weeks. The fifth document exclusively deals with cryptocurrencies and will be unveiled by the time the sixth month of the next fiscal year comes to an end in September 2018. As CBI has announced, it will be a regulatory framework instead of clear-cut regulations. Firouzabadi said Iranâ€™s central bank, like that of many other nations, has not come to a stable and defined stance on Bitcoin, noting that many countries look at it as a potentially dangerous option in light of its violent price fluctuations and investment risk. Less than two weeks ago, the head of CBIâ€™s Innovative Technologies Department, Nasser Hakimi, asked investors and the public to refrain from dealing with virtual currencies without proper knowledge and to remain cautious. â€œMechanisms of control and supervision over the supply of cryptocurrencies are being implemented through the collaboration of the central bank and related entities, but the people must be aware of their risks and dangers on the demand side,â€ he added. Around the same days, Bitcoin had experienced its third steep decline of the year to stoop lower than $6,000 after briefly skyrocketing to around $7,800. In the two weeks since, it reached yet another staggering high of more than $8,300. The cryptocurrency is priced just shy of $8,200 as of this writing, while Iranians can purchase one at roughly 350 million rials ($8,400). The HCC secretary said that in light of the ease of use and anonymity of Bitcoin, high investment profits and lack of any transaction fees, it has emerged as a cataclysmic change in banking and online businesses. â€œOur view regarding Bitcoin is positive, but it does not mean that we will not require regulations in this regard because following the rules is a must,â€ he said. Firouzabadi said he hopes CBIâ€™s stance toward cryptocurrencies will soon be clarified, adding that HCC will continue to conduct studies and evaluate pros and cons of virtual currencies."
print("Original:", sample_text)
print("Cleaned:", clean_text(sample_text))
# Out:
# Original: Iranâ€™s High Council of Cyberspace, one of the main entities deciding the fate of virtual currencies in Iran, has welcomed the idea of Bitcoin and other cryptocurrencies if they are harnessed by clearly-stated regulations. â€œWe [at the HCC] welcome Bitcoin, but we must have regulations for Bitcoin and any other digital currency. Studies are necessary for considering a new currency,â€ Abolhassan Firouzabadi, HCC secretary, told ILNA. He said HCC and the Central Bank of Iran are currently studying virtual currencies, as they have captured the attention of the world. However, he points out that even though the CBI has yet to devise definitive regulations for Bitcoin and similar currencies, â€œmany in Iran are dealing with Bitcoin, be it purchasing, selling or mining it, and even dealing with it in exchange shops, creating content and establishing startupsâ€. CBI has envisioned six documents on fintechs and cryptocurrencies that will be unveiled by the end of the next fiscal year in March 2019. Two of them, dealing with payment initiators and payment facilitators, have already been published with a third covering micropayments and related technologies in fintech to be announced in the next few weeks. The fifth document exclusively deals with cryptocurrencies and will be unveiled by the time the sixth month of the next fiscal year comes to an end in September 2018. As CBI has announced, it will be a regulatory framework instead of clear-cut regulations. Firouzabadi said Iranâ€™s central bank, like that of many other nations, has not come to a stable and defined stance on Bitcoin, noting that many countries look at it as a potentially dangerous option in light of its violent price fluctuations and investment risk. Less than two weeks ago, the head of CBIâ€™s Innovative Technologies Department, Nasser Hakimi, asked investors and the public to refrain from dealing with virtual currencies without proper knowledge and to remain cautious. â€œMechanisms of control and supervision over the supply of cryptocurrencies are being implemented through the collaboration of the central bank and related entities, but the people must be aware of their risks and dangers on the demand side,â€ he added. Around the same days, Bitcoin had experienced its third steep decline of the year to stoop lower than $6,000 after briefly skyrocketing to around $7,800. In the two weeks since, it reached yet another staggering high of more than $8,300. The cryptocurrency is priced just shy of $8,200 as of this writing, while Iranians can purchase one at roughly 350 million rials ($8,400). The HCC secretary said that in light of the ease of use and anonymity of Bitcoin, high investment profits and lack of any transaction fees, it has emerged as a cataclysmic change in banking and online businesses. â€œOur view regarding Bitcoin is positive, but it does not mean that we will not require regulations in this regard because following the rules is a must,â€ he said. Firouzabadi said he hopes CBIâ€™s stance toward cryptocurrencies will soon be clarified, adding that HCC will continue to conduct studies and evaluate pros and cons of virtual currencies.
# Cleaned: irans high council of cyberspace, one of the main entities deciding the fate of virtual currencies in iran, has welcomed the idea of bitcoin and other cryptocurrencies if they are harnessed by clearlystated regulations. we at the hcc welcome bitcoin, but we must have regulations for bitcoin and any other digital currency. studies are necessary for considering a new currency, abolhassan firouzabadi, hcc secretary, told ilna. he said hcc and the central bank of iran are currently studying virtual currencies, as they have captured the attention of the world. however, he points out that even though the cbi has yet to devise definitive regulations for bitcoin and similar currencies, many in iran are dealing with bitcoin, be it purchasing, selling or mining it, and even dealing with it in exchange shops, creating content and establishing startups. cbi has envisioned six documents on fintechs and cryptocurrencies that will be unveiled by the end of the next fiscal year in march 2019. two of them, dealing with payment initiators and payment facilitators, have already been published with a third covering micropayments and related technologies in fintech to be announced in the next few weeks. the fifth document exclusively deals with cryptocurrencies and will be unveiled by the time the sixth month of the next fiscal year comes to an end in september 2018. as cbi has announced, it will be a regulatory framework instead of clearcut regulations. firouzabadi said irans central bank, like that of many other nations, has not come to a stable and defined stance on bitcoin, noting that many countries look at it as a potentially dangerous option in light of its violent price fluctuations and investment risk. less than two weeks ago, the head of cbis innovative technologies department, nasser hakimi, asked investors and the public to refrain from dealing with virtual currencies without proper knowledge and to remain cautious. mechanisms of control and supervision over the supply of cryptocurrencies are being implemented through the collaboration of the central bank and related entities, but the people must be aware of their risks and dangers on the demand side, he added. around the same days, bitcoin had experienced its third steep decline of the year to stoop lower than 6,000 after briefly skyrocketing to around 7,800. in the two weeks since, it reached yet another staggering high of more than 8,300. the cryptocurrency is priced just shy of 8,200 as of this writing, while iranians can purchase one at roughly 350 million rials 8,400. the hcc secretary said that in light of the ease of use and anonymity of bitcoin, high investment profits and lack of any transaction fees, it has emerged as a cataclysmic change in banking and online businesses. our view regarding bitcoin is positive, but it does not mean that we will not require regulations in this regard because following the rules is a must, he said. firouzabadi said he hopes cbis stance toward cryptocurrencies will soon be clarified, adding that hcc will continue to conduct studies and evaluate pros and cons of virtual currencies.

# %% [markdown]
# ## Dataset and Model Loading

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, BartForConditionalGeneration

# Load CNN/DailyMail dataset
dataset = load_dataset("cnn_dailymail", "3.0.0")
tokenizer = AutoTokenizer.from_pretrained("facebook/bart-large-cnn")
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

print("Dataset and model loaded successfully.")
# Out:
# WARNING:datasets.builder:Using custom data configuration 1.0.0-9039e3832de1dbcc
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/parquet/1.0.0-9039e3832de1dbcc/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/datasets/table.py:1427: FutureWarning: promote has been superseded by promote_options='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-cnn and are newly initialized: ['model.shared.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Dataset and model loaded successfully.

# %% [markdown]
# ## Fine-Tuning Setup

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, BartForConditionalGeneration, Trainer, TrainingArguments
import torch

# Free up GPU memory
torch.cuda.empty_cache()

# Load and preprocess dataset
dataset = load_dataset("cnn_dailymail", "3.0.0")

# Initialize tokenizer and model with a smaller variant
tokenizer = AutoTokenizer.from_pretrained("facebook/bart-base")  # Switch to bart-base
model = BartForConditionalGeneration.from_pretrained("facebook/bart-base")  # Use bart-base

# Preprocessing function
def preprocess_function(examples):
    inputs = tokenizer(examples['article'], max_length=512, truncation=True, padding="max_length")
    labels = tokenizer(examples['highlights'], max_length=64, truncation=True, padding="max_length")
    inputs["labels"] = labels["input_ids"]
    return inputs

# Use a smaller subset of the dataset for faster iterations
small_train_dataset = dataset['train'].shuffle(seed=42).select(range(1000))
small_val_dataset = dataset['validation'].shuffle(seed=42).select(range(500))

# Apply preprocessing function
tokenized_datasets = small_train_dataset.map(preprocess_function, batched=True)
tokenized_datasets_val = small_val_dataset.map(preprocess_function, batched=True)

# Define training arguments
training_args = TrainingArguments(
    output_dir="./results",
    evaluation_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=4,  # Reduce batch size
    gradient_accumulation_steps=4,  # Accumulate gradients to simulate larger batch size
    num_train_epochs=1,  # Only train for 1 epoch for testing
    weight_decay=0.01,
    save_strategy="no",  # No need to save models during quick testing
    fp16=True,  # Mixed precision training
    dataloader_num_workers=4,  # Use 4 CPU workers for faster data loading
    logging_steps=50,  # Log every 50 steps
    report_to="none",  # Disable W&B logging for now
)

# Initialize Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets,
    eval_dataset=tokenized_datasets_val,
    tokenizer=tokenizer
)

# Train the model
trainer.train()
# Out:
# WARNING:datasets.builder:Using custom data configuration 1.0.0-9039e3832de1dbcc
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/parquet/1.0.0-9039e3832de1dbcc/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/3 [00:00<?, ?it/s]
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/parquet/1.0.0-9039e3832de1dbcc/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-28e98eee1b8e7a1a.arrow
# WARNING:datasets.arrow_dataset:Loading cached shuffled indices for dataset at /root/.cache/huggingface/datasets/parquet/1.0.0-9039e3832de1dbcc/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-bc1437ea8d77b32e.arrow
# WARNING:datasets.arrow_dataset:Loading cached processed dataset at /root/.cache/huggingface/datasets/parquet/1.0.0-9039e3832de1dbcc/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec/cache-214ef86a4ec6d26a.arrow
#   0%|          | 0/1 [00:00<?, ?ba/s]
# Using cuda_amp half precision backend
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:593: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()
# The following columns in the training set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: article, highlights, id. If article, highlights, id are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 1000
#   Num Epochs = 1
#   Instantaneous batch size per device = 4
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 4
#   Total optimization steps = 62
#   Number of trainable parameters = 139420416
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:2504: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   else torch.cuda.amp.autocast(cache_enabled=cache_enabled, dtype=self.amp_dtype)
#     <div>
#
#       <progress value='62' max='62' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [62/62 00:41, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.680300</td>
#       <td>2.357327</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set don't have a corresponding argument in `BartForConditionalGeneration.forward` and have been ignored: article, highlights, id. If article, highlights, id are not expected by `BartForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 500
#   Batch size = 8
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=62, training_loss=3.5461487923899004, metrics={'train_runtime': 42.7969, 'train_samples_per_second': 23.366, 'train_steps_per_second': 1.449, 'total_flos': 302429283287040.0, 'train_loss': 3.5461487923899004, 'epoch': 0.99})

# %%
def generate_summary(article_texts, model, tokenizer):
    inputs = tokenizer(article_texts, max_length=1024, return_tensors="pt", truncation=True, padding=True)
    input_ids = inputs["input_ids"].to(model.device)

    # Generate summaries
    summary_ids = model.generate(input_ids, max_length=150, num_beams=4, length_penalty=2.0, early_stopping=True)

    # Decode and return summaries
    summaries = [tokenizer.decode(summary_id, skip_special_tokens=True) for summary_id in summary_ids]
    return summaries

# Sample articles from the validation dataset for summary generation
sample_articles = ["Iranâ€™s High Council of Cyberspace, one of the main entities deciding the fate of virtual currencies in Iran, has welcomed the idea of Bitcoin and other cryptocurrencies if they are harnessed by clearly-stated regulations. â€œWe [at the HCC] welcome Bitcoin, but we must have regulations for Bitcoin and any other digital currency. Studies are necessary for considering a new currency,â€ Abolhassan Firouzabadi, HCC secretary, told ILNA. He said HCC and the Central Bank of Iran are currently studying virtual currencies, as they have captured the attention of the world. However, he points out that even though the CBI has yet to devise definitive regulations for Bitcoin and similar currencies, â€œmany in Iran are dealing with Bitcoin, be it purchasing, selling or mining it, and even dealing with it in exchange shops, creating content and establishing startupsâ€. CBI has envisioned six documents on fintechs and cryptocurrencies that will be unveiled by the end of the next fiscal year in March 2019. Two of them, dealing with payment initiators and payment facilitators, have already been published with a third covering micropayments and related technologies in fintech to be announced in the next few weeks. The fifth document exclusively deals with cryptocurrencies and will be unveiled by the time the sixth month of the next fiscal year comes to an end in September 2018. As CBI has announced, it will be a regulatory framework instead of clear-cut regulations. Firouzabadi said Iranâ€™s central bank, like that of many other nations, has not come to a stable and defined stance on Bitcoin, noting that many countries look at it as a potentially dangerous option in light of its violent price fluctuations and investment risk. Less than two weeks ago, the head of CBIâ€™s Innovative Technologies Department, Nasser Hakimi, asked investors and the public to refrain from dealing with virtual currencies without proper knowledge and to remain cautious. â€œMechanisms of control and supervision over the supply of cryptocurrencies are being implemented through the collaboration of the central bank and related entities, but the people must be aware of their risks and dangers on the demand side,â€ he added. Around the same days, Bitcoin had experienced its third steep decline of the year to stoop lower than $6,000 after briefly skyrocketing to around $7,800. In the two weeks since, it reached yet another staggering high of more than $8,300. The cryptocurrency is priced just shy of $8,200 as of this writing, while Iranians can purchase one at roughly 350 million rials ($8,400). The HCC secretary said that in light of the ease of use and anonymity of Bitcoin, high investment profits and lack of any transaction fees, it has emerged as a cataclysmic change in banking and online businesses. â€œOur view regarding Bitcoin is positive, but it does not mean that we will not require regulations in this regard because following the rules is a must,â€ he said. Firouzabadi said he hopes CBIâ€™s stance toward cryptocurrencies will soon be clarified, adding that HCC will continue to conduct studies and evaluate pros and cons of virtual currencies."]  # Using first 5 articles from the validation set

# Generate summaries for these articles
generated_summaries = generate_summary(sample_articles, model, tokenizer)

# Display the generated summaries
for i, summary in enumerate(generated_summaries):
    print(f"Generated Summary {i+1}: {summary}\n")
# Out:
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
# Generated Summary 1: Abolhassan Firouzabadi, HCC secretary, told ILNA that the CBI has yet to devise definitive regulations for Bitcoin and other digital currencies.
# The HCC is currently studying the pros and cons of virtual currencies, he said.
# It will be a regulatory framework instead of clear-cut regulations, he added.

# %% [markdown]
# ## Evaluation and Metrics

# %%
from datasets import load_metric
import torch
from transformers import AutoTokenizer, BartForConditionalGeneration

# Load ROUGE metric
rouge = load_metric("rouge")

# Sample input for evaluation
sample_inputs = ["Iranâ€™s High Council of Cyberspace, one of the main entities deciding the fate of virtual currencies in Iran, has welcomed the idea of Bitcoin and other cryptocurrencies if they are harnessed by clearly-stated regulations. â€œWe [at the HCC] welcome Bitcoin, but we must have regulations for Bitcoin and any other digital currency. Studies are necessary for considering a new currency,â€ Abolhassan Firouzabadi, HCC secretary, told ILNA. He said HCC and the Central Bank of Iran are currently studying virtual currencies, as they have captured the attention of the world. However, he points out that even though the CBI has yet to devise definitive regulations for Bitcoin and similar currencies, â€œmany in Iran are dealing with Bitcoin, be it purchasing, selling or mining it, and even dealing with it in exchange shops, creating content and establishing startupsâ€. CBI has envisioned six documents on fintechs and cryptocurrencies that will be unveiled by the end of the next fiscal year in March 2019. Two of them, dealing with payment initiators and payment facilitators, have already been published with a third covering micropayments and related technologies in fintech to be announced in the next few weeks. The fifth document exclusively deals with cryptocurrencies and will be unveiled by the time the sixth month of the next fiscal year comes to an end in September 2018. As CBI has announced, it will be a regulatory framework instead of clear-cut regulations. Firouzabadi said Iranâ€™s central bank, like that of many other nations, has not come to a stable and defined stance on Bitcoin, noting that many countries look at it as a potentially dangerous option in light of its violent price fluctuations and investment risk. Less than two weeks ago, the head of CBIâ€™s Innovative Technologies Department, Nasser Hakimi, asked investors and the public to refrain from dealing with virtual currencies without proper knowledge and to remain cautious. â€œMechanisms of control and supervision over the supply of cryptocurrencies are being implemented through the collaboration of the central bank and related entities, but the people must be aware of their risks and dangers on the demand side,â€ he added. Around the same days, Bitcoin had experienced its third steep decline of the year to stoop lower than $6,000 after briefly skyrocketing to around $7,800. In the two weeks since, it reached yet another staggering high of more than $8,300. The cryptocurrency is priced just shy of $8,200 as of this writing, while Iranians can purchase one at roughly 350 million rials ($8,400). The HCC secretary said that in light of the ease of use and anonymity of Bitcoin, high investment profits and lack of any transaction fees, it has emerged as a cataclysmic change in banking and online businesses. â€œOur view regarding Bitcoin is positive, but it does not mean that we will not require regulations in this regard because following the rules is a must,â€ he said. Firouzabadi said he hopes CBIâ€™s stance toward cryptocurrencies will soon be clarified, adding that HCC will continue to conduct studies and evaluate pros and cons of virtual currencies."]

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("facebook/bart-large-cnn")
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

# Move the model to GPU (if available)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Tokenize input
tokenized_inputs = tokenizer(sample_inputs, max_length=1024, return_tensors="pt", truncation=True)

# Move tokenized inputs to the same device as the model
tokenized_inputs = {key: value.to(device) for key, value in tokenized_inputs.items()}

# Generate summary
summary_ids = model.generate(tokenized_inputs["input_ids"], max_length=50, min_length=10, length_penalty=2.0)

# Decode the summaries
decoded_summaries = [tokenizer.decode(g, skip_special_tokens=True) for g in summary_ids]
print("Generated Summary:", decoded_summaries)

# Ground truth for evaluation
reference_summaries = ["Iran open to cryptocurrencies, planning new regulations"]

# Compute ROUGE score
rouge_score = rouge.compute(predictions=decoded_summaries, references=reference_summaries)
print("ROUGE Score:", rouge_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-large-cnn/snapshots/37f520fa929c961707657b28798b30c003dd100b/config.json
# Model config BartConfig {
#   "_name_or_path": "facebook/bart-large-cnn",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "force_bos_token_to_be_generated": true,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "max_position_embeddings": 1024,
#   "min_length": 56,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": " ",
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4
#     }
#   },
#   "transformers_version": "4.26.1",
#   "use_cache": true,
#   "vocab_size": 50264
# }
#
# loading file vocab.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-large-cnn/snapshots/37f520fa929c961707657b28798b30c003dd100b/vocab.json
# loading file merges.txt from cache at /root/.cache/huggingface/hub/models--facebook--bart-large-cnn/snapshots/37f520fa929c961707657b28798b30c003dd100b/merges.txt
# loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-large-cnn/snapshots/37f520fa929c961707657b28798b30c003dd100b/tokenizer.json
# loading file added_tokens.json from cache at None
# loading file special_tokens_map.json from cache at None
# loading file tokenizer_config.json from cache at None
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-large-cnn/snapshots/37f520fa929c961707657b28798b30c003dd100b/config.json
# Model config BartConfig {
#   "_name_or_path": "facebook/bart-large-cnn",
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "force_bos_token_to_be_generated": true,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "max_position_embeddings": 1024,
#   "min_length": 56,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": " ",
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4
#     }
#   },
#   "transformers_version": "4.26.1",
#   "use_cache": true,
#   "vocab_size": 50264
# }
#
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-large-cnn/snapshots/37f520fa929c961707657b28798b30c003dd100b/config.json
# Model config BartConfig {
#   "_num_labels": 3,
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 0,
#   "classif_dropout": 0.0,
#   "classifier_dropout": 0.0,
#   "d_model": 1024,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 4096,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 12,
#   "decoder_start_token_id": 2,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 4096,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 12,
#   "eos_token_id": 2,
#   "force_bos_token_to_be_generated": true,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1",
#     "2": "LABEL_2"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "label2id": {
#     "LABEL_0": 0,
#     "LABEL_1": 1,
#     "LABEL_2": 2
#   },
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "max_position_embeddings": 1024,
#   "min_length": 56,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "num_beams": 4,
#   "num_hidden_layers": 12,
#   "output_past": true,
#   "pad_token_id": 1,
#   "prefix": " ",
#   "scale_embedding": false,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 142,
#       "min_length": 56,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4
#     }
#   },
#   "transformers_version": "4.26.1",
#   "use_cache": true,
#   "vocab_size": 50264
# }
#
# loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--facebook--bart-large-cnn/snapshots/37f520fa929c961707657b28798b30c003dd100b/model.safetensors
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "min_length": 56,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# All model checkpoint weights were used when initializing BartForConditionalGeneration.
#
# Some weights of BartForConditionalGeneration were not initialized from the model checkpoint at facebook/bart-large-cnn and are newly initialized: ['model.shared.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--facebook--bart-large-cnn/snapshots/37f520fa929c961707657b28798b30c003dd100b/generation_config.json
# Generate config GenerationConfig {
#   "_from_model_config": true,
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "min_length": 56,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
#
# Generate config GenerationConfig {
#   "bos_token_id": 0,
#   "decoder_start_token_id": 2,
#   "early_stopping": true,
#   "eos_token_id": 2,
#   "forced_bos_token_id": 0,
#   "forced_eos_token_id": 2,
#   "length_penalty": 2.0,
#   "max_length": 142,
#   "min_length": 56,
#   "no_repeat_ngram_size": 3,
#   "num_beams": 4,
#   "pad_token_id": 1,
#   "transformers_version": "4.26.1"
# }
# Generated Summary: ["Iran's High Council of Cyberspace has welcomed the idea of Bitcoin and other cryptocurrencies if they are harnessed by clearly-stated regulations. CBI has envisioned six documents on fintechs and cryptocurrencies that will be unveiled by the end"]
# ROUGE Score: {'rouge1': AggregateScore(low=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565), mid=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565), high=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565)), 'rouge2': AggregateScore(low=Score(precision=0.0, recall=0.0, fmeasure=0.0), mid=Score(precision=0.0, recall=0.0, fmeasure=0.0), high=Score(precision=0.0, recall=0.0, fmeasure=0.0)), 'rougeL': AggregateScore(low=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565), mid=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565), high=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565)), 'rougeLsum': AggregateScore(low=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565), mid=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565), high=Score(precision=0.07692307692307693, recall=0.42857142857142855, fmeasure=0.13043478260869565))}

# %% [markdown]
# ## Deployment Preparation

# %%
# Save the model and tokenizer
model.save_pretrained("./saved_model")
tokenizer.save_pretrained("./saved_model")

print("Model and tokenizer exported successfully.")
# Out:
# Configuration saved in ./saved_model/config.json
# Configuration saved in ./saved_model/generation_config.json
# Model weights saved in ./saved_model/pytorch_model.bin
# tokenizer config file saved in ./saved_model/tokenizer_config.json
# Special tokens file saved in ./saved_model/special_tokens_map.json
# Model and tokenizer exported successfully.
